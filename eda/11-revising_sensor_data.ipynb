# %%
import sys
sys.path.append('../')
from common import get_sensor, process_sensor_dataframe, load_clean_train

# %%
snsr = process_sensor_dataframe()
# Out:
# loading cached copy
# Time it took: 10.060471057891846

# %%
snsr.shape
# Out:
# (7902291, 22)

# %%
snsr.head(10)
# Out:
#   BLOCK_ID  STREET_NAME  BLOCK_NUM      STREET_BLOCK   PM_DISTRICT_NAME  RATE  \
# 0    41522  FILLMORE ST       22.0  FILLMORE ST 2200           Fillmore   NaN
# 1    41524  FILLMORE ST       24.0  FILLMORE ST 2400           Fillmore   NaN
# 2    50001   JACKSON ST        1.0    JACKSON ST 100           Downtown   NaN
# 3    50002   JACKSON ST        2.0    JACKSON ST 200           Downtown   NaN
# 4    10903     09TH AVE        3.0      09TH AVE 300     Inner Richmond   NaN
# 5    11003     10TH AVE        3.0      10TH AVE 300     Inner Richmond   NaN
# 6    11428     14TH AVE       28.0     14TH AVE 2800        West Portal   NaN
# 7    33901     BERRY ST        1.0      BERRY ST 100  South Embarcadero   NaN
# 8    33902     BERRY ST        2.0      BERRY ST 200  South Embarcadero   NaN
# 9    41531  FILLMORE ST       31.0  FILLMORE ST 3100             Marina   NaN
#
#         START_TIME_DT  tot_spaces  occ_spaces  vac_spaces   ...     \
# ...
