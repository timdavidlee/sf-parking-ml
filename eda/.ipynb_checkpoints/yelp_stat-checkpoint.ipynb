# %%
import pandas as pd
import numpy as np
import json
import requests
import sys
from multiprocessing import cpu_count, Pool
sys.path.append('../')
from common import get_train, feat_eng,get_test, REF_PATH
from collections import defaultdict

# %%
with open('/Users/timlee/Dropbox/keys/yelp_api.txt') as f:
    client, api_key, secret   = f.read().strip().split(',')

# %%
train_df = get_train()
train_df = feat_eng(train_df)

test_df = get_test()
test_df = feat_eng(test_df)

all_df = pd.concat([train_df, test_df])
print(all_df.shape)


uniq_coord = all_df.groupby(['From_lat','From_long'])[['pop']].count().reset_index()
uniq_coord.columns = ['lat','lon', 'ct']
uniq_coord['id'] = uniq_coord.index
from_uniq_coord = uniq_coord[['id','lat','lon']].copy()

uniq_coord = train_df.groupby(['To_lat','To_long'])[['pop']].count().reset_index()
uniq_coord.columns = ['lat','lon', 'ct']
uniq_coord['id'] = uniq_coord.index
to_uniq_coord = uniq_coord[['id','lat','lon']].copy()
# Out:
# Time it took: 0.16450095176696777
# adding additional features to test and/or train ...
#
# loading parking data 1.7M
# loading address data 30K
# calculating closest joins
# merging
# complete
# fixing neighborhood string formatting
# merging in neighborhood information
# Time it took: 0.6995618343353271
# Time it took: 0.09803271293640137
# adding additional features to test and/or train ...
#
# loading parking data 1.7M
# loading address data 30K
# calculating closest joins
# merging
# complete
# fixing neighborhood string formatting
# merging in neighborhood information
# Time it took: 0.48969483375549316
# (1886, 49)

# %%
def start_job(gpslst):
    """
    generic parallelizing class
    """    
    cores = cpu_count() - 1 # for other processes

    data_split = np.array_split(gpslst, cores)
    pool = Pool(cores)
    pool.map(search_gps_list, data_split)
    pool.close()
    pool.join()

    
def search_gps_list(gpslst, reset=False):
    if reset:
        with open( REF_PATH + 'yelp_api_json.json', 'w') as f:
            f.write('')
            
    for idx, lat, lon in gpslst.values:
        yelp_search_coord(lat, lon, idx)

        
def yelp_search_coord(lat, lon, idx=0):

    REF_PATH = '/Users/timlee/myrepos/final-project-chengcheng-tim/ref_data/'
    
    biz_search = 'https://api.yelp.com/v3/businesses/search'
    
    data = {'grant_type': 'client_credentials',
            'client_id': client,
            'client_secret': secret}
    token = requests.post('https://api.yelp.com/oauth2/token', data=data)
    access_token = token.json()['access_token']
    headers = {'Authorization': 'bearer %s' % access_token}
    
    total_ct = 1
    rem_ct = total_ct
    index = 0
    while index < total_ct:
        
        params = {
            'location':'San Francisco'
            , 'latitude': lat #37.749044
            , 'longitude' : lon #-122.418166
            , 'radius': 500 # in meteres
            , 'limit' : 50
        }
        
        if index > 0:
            params['offset'] = index


        resp = requests.get(biz_search, headers=headers, params=params)
        biz_j = json.loads(resp.content)
        if biz_j.get('businesses') is None:
            break
        else:
            batch_ct = len(biz_j.get('businesses'))

            print(resp.status_code, idx, biz_j['total'], index )

            with open( REF_PATH + 'yelp_api_json.json', 'a') as f:
                out = {idx : biz_j}
                json.dump(out, f)
                f.write('\n')

            if index == 0:
                total_ct = biz_j['total']
                remaining_ct = total_ct - biz_j['total']
                index = batch_ct
            else:
                remaining_ct -= batch_ct
                index += batch_ct

# %%
search_gps_list(to_uniq_coord, True)
# Out:
# 200 0.0 319 0
# 200 0.0 319 50
# 200 0.0 319 100
# 200 0.0 319 150
# 200 0.0 319 200
# 200 0.0 319 250
# 200 0.0 319 300
# 200 1.0 391 0
# 200 1.0 391 50
# 200 1.0 391 100
# 200 1.0 391 150
# 200 1.0 391 200
# 200 1.0 391 250
# 200 1.0 391 300
# 200 1.0 391 350
# 200 2.0 395 0
# 200 2.0 395 50
# 200 2.0 395 100
# 200 2.0 395 150
# 200 2.0 395 200
# 200 2.0 395 250
# 200 2.0 395 300
# 200 2.0 395 350
# 200 3.0 421 0
# 200 3.0 421 50
# 200 3.0 421 100
# 200 3.0 421 150
# 200 3.0 421 200
# 200 3.0 421 250
# 200 3.0 421 300
# 200 3.0 421 350
# 200 3.0 421 400
# 200 4.0 238 0
# 200 4.0 238 50
# 200 4.0 238 100
# 200 4.0 238 150
# 200 4.0 238 200
# 200 5.0 639 0
# 200 5.0 639 50
# 200 5.0 639 100
# 200 5.0 639 150
# 200 5.0 639 200
# 200 5.0 639 250
# 200 5.0 639 300
# 200 5.0 639 350
# 200 5.0 639 400
# 200 5.0 639 450
# 200 5.0 639 500
# 200 5.0 639 550
# 200 5.0 639 600
# 200 6.0 644 0
# 200 6.0 644 50
# 200 6.0 644 100
# 200 6.0 644 150
# 200 6.0 644 200
# 200 6.0 644 250
# 200 6.0 644 300
# 200 6.0 644 350
# 200 6.0 644 400
# 200 6.0 644 450
# 200 6.0 644 500
# 200 6.0 644 550
# 200 6.0 644 600
# 200 7.0 776 0
# 200 7.0 776 50
# 200 7.0 776 100
# 200 7.0 776 150
# 200 7.0 776 200
# 200 7.0 776 250
# 200 7.0 776 300
# 200 7.0 776 350
# 200 7.0 776 400
# 200 7.0 776 450
# 200 7.0 776 500
# 200 7.0 776 550
# 200 7.0 776 600
# 200 7.0 776 650
# 200 7.0 776 700
# 200 7.0 776 750
# 200 8.0 860 0
# 200 8.0 860 50
# 200 8.0 860 100
# 200 8.0 860 150
# 200 8.0 860 200
# 200 8.0 860 250
# 200 8.0 860 300
# 200 8.0 860 350
# 200 8.0 860 400
# 200 8.0 860 450
# 200 8.0 860 500
# 200 8.0 860 550
# 200 8.0 860 600
# 200 8.0 860 650
# 200 8.0 860 700
# 200 8.0 860 750
# 200 8.0 860 800
# 200 8.0 860 850
# 200 9.0 725 0
# 200 9.0 725 50
# 200 9.0 725 100
# 200 9.0 725 150
# 200 9.0 725 200
# 200 9.0 725 250
# 200 9.0 725 300
# 200 9.0 725 350
# 200 9.0 725 400
# 200 9.0 725 450
# 200 9.0 725 500
# 200 9.0 725 550
# 200 9.0 725 600
# 200 9.0 725 650
# 200 9.0 725 700
# 200 10.0 885 0
# 200 10.0 885 50
# 200 10.0 885 100
# 200 10.0 885 150
# 200 10.0 885 200
# 200 10.0 885 250
# 200 10.0 885 300
# 200 10.0 885 350
# 200 10.0 885 400
# 200 10.0 885 450
# 200 10.0 885 500
# 200 10.0 885 550
# 200 10.0 885 600
# 200 10.0 885 650
# 200 10.0 885 700
# 200 10.0 885 750
# 200 10.0 885 800
# 200 10.0 885 850
# 200 11.0 784 0
# 200 11.0 784 50
# 200 11.0 784 100
# 200 11.0 784 150
# 200 11.0 784 200
# 200 11.0 784 250
# 200 11.0 784 300
# 200 11.0 784 350
# 200 11.0 784 400
# 200 11.0 784 450
# 200 11.0 784 500
# 200 11.0 784 550
# 200 11.0 784 600
# 200 11.0 784 650
# 200 11.0 784 700
# 200 11.0 784 750
# 200 12.0 892 0
# 200 12.0 892 50
# 200 12.0 892 100
# 200 12.0 892 150
# 200 12.0 892 200
# 200 12.0 892 250
# 200 12.0 892 300
# 200 12.0 892 350
# 200 12.0 892 400
# 200 12.0 892 450
# 200 12.0 892 500
# 200 12.0 892 550
# 200 12.0 892 600
# 200 12.0 892 650
# 200 12.0 892 700
# 200 12.0 892 750
# 200 12.0 892 800
# 200 12.0 892 850
# 200 13.0 743 0
# 200 13.0 743 50
# 200 13.0 743 100
# 200 13.0 743 150
# 200 13.0 743 200
# 200 13.0 743 250
# 200 13.0 743 300
# 200 13.0 743 350
# 200 13.0 743 400
# 200 13.0 743 450
# 200 13.0 743 500
# 200 13.0 743 550
# 200 13.0 743 600
# 200 13.0 743 650
# 200 13.0 743 700
# 200 14.0 974 0
# 200 14.0 974 50
# 200 14.0 974 100
# 200 14.0 974 150
# 200 14.0 974 200
# 200 14.0 974 250
# 200 14.0 974 300
# 200 14.0 974 350
# 200 14.0 974 400
# 200 14.0 974 450
# 200 14.0 974 500
# 200 14.0 974 550
# 200 14.0 974 600
# 200 14.0 974 650
# 200 14.0 974 700
# 200 14.0 974 750
# 200 14.0 974 800
# 200 14.0 974 850
# 200 14.0 974 900
# 200 14.0 974 950
# 200 15.0 737 0
# 200 15.0 737 50
# 200 15.0 737 100
# 200 15.0 737 150
# 200 15.0 737 200
# 200 15.0 737 250
# 200 15.0 737 300
# 200 15.0 737 350
# 200 15.0 737 400
# 200 15.0 737 450
# 200 15.0 737 500
# 200 15.0 737 550
# 200 15.0 737 600
# 200 15.0 737 650
# 200 15.0 737 700
# 200 16.0 681 0
# 200 16.0 681 50
# 200 16.0 681 100
# 200 16.0 681 150
# 200 16.0 681 200
# 200 16.0 681 250
# 200 16.0 681 300
# 200 16.0 681 350
# 200 16.0 681 400
# 200 16.0 681 450
# 200 16.0 681 500
# 200 16.0 681 550
# 200 16.0 681 600
# 200 16.0 681 650
# 200 17.0 891 0
# 200 17.0 891 50
# 200 17.0 891 100
# 200 17.0 891 150
# 200 17.0 891 200
# 200 17.0 891 250
# 200 17.0 891 300
# 200 17.0 891 350
# 200 17.0 891 400
# 200 17.0 891 450
# 200 17.0 891 500
# 200 17.0 891 550
# 200 17.0 891 600
# 200 17.0 891 650
# 200 17.0 891 700
# 200 17.0 891 750
# 200 17.0 891 800
# 200 17.0 891 850
# 200 18.0 734 0
# 200 18.0 734 50
# 200 18.0 734 100
# 200 18.0 734 150
# 200 18.0 734 200
# 200 18.0 734 250
# 200 18.0 734 300
# 200 18.0 734 350
# 200 18.0 734 400
# 200 18.0 734 450
# 200 18.0 734 500
# 200 18.0 734 550
# 200 18.0 734 600
# 200 18.0 734 650
# 200 18.0 734 700
# 200 19.0 717 0
# 200 19.0 717 50
# 200 19.0 717 100
# 200 19.0 717 150
# 200 19.0 717 200
# 200 19.0 717 250
# 200 19.0 717 300
# 200 19.0 717 350
# 200 19.0 717 400
# 200 19.0 717 450
# 200 19.0 717 500
# 200 19.0 717 550
# 200 19.0 717 600
# 200 19.0 717 650
# 200 19.0 717 700
# 200 20.0 792 0
# 200 20.0 792 50
# 200 20.0 792 100
# 200 20.0 792 150
# 200 20.0 792 200
# 200 20.0 792 250
# 200 20.0 792 300
# 200 20.0 792 350
# 200 20.0 792 400
# 200 20.0 792 450
# 200 20.0 792 500
# 200 20.0 792 550
# 200 20.0 792 600
# 200 20.0 792 650
# 200 20.0 792 700
# 200 20.0 792 750
# 200 21.0 858 0
# 200 21.0 858 50
# 200 21.0 858 100
# 200 21.0 858 150
# 200 21.0 858 200
# 200 21.0 858 250
# 200 21.0 858 300
# 200 21.0 858 350
# 200 21.0 858 400
# 200 21.0 858 450
# 200 21.0 858 500
# 200 21.0 858 550
# 200 21.0 858 600
# 200 21.0 858 650
# 200 21.0 858 700
# 200 21.0 858 750
# 200 21.0 858 800
# 200 21.0 858 850
# 200 22.0 1000 0
# 200 22.0 1000 50
# 200 22.0 1000 100
# 200 22.0 1000 150
# 200 22.0 1000 200
# 200 22.0 1000 250
# 200 22.0 1000 300
# 200 22.0 1000 350
# 200 22.0 1000 400
# 200 22.0 1000 450
# 200 22.0 1000 500
# 200 22.0 1000 550
# 200 22.0 1000 600
# 200 22.0 1000 650
# 200 22.0 1000 700
# 200 22.0 1000 750
# 200 22.0 1000 800
# 200 22.0 1000 850
# 200 22.0 1000 900
# 200 22.0 1000 950
# 200 23.0 970 0
# 200 23.0 970 50
# 200 23.0 970 100
# 200 23.0 970 150
# 200 23.0 970 200
# 200 23.0 970 250
# 200 23.0 970 300
# 200 23.0 970 350
# 200 23.0 970 400
# 200 23.0 970 450
# 200 23.0 970 500
# 200 23.0 970 550
# 200 23.0 970 600
# 200 23.0 970 650
# 200 23.0 970 700
# 200 23.0 970 750
# 200 23.0 970 800
# 200 23.0 970 850
# 200 23.0 970 900
# 200 23.0 970 950
# 200 24.0 913 0
# 200 24.0 913 50
# 200 24.0 913 100
# 200 24.0 913 150
# 200 24.0 913 200
# 200 24.0 913 250
# 200 24.0 913 300
# 200 24.0 913 350
# 200 24.0 913 400
# 200 24.0 913 450
# 200 24.0 913 500
# 200 24.0 913 550
# 200 24.0 913 600
# 200 24.0 913 650
# 200 24.0 913 700
# 200 24.0 913 750
# 200 24.0 913 800
# 200 24.0 913 850
# 200 24.0 913 900
# 200 25.0 661 0
# 200 25.0 661 50
# 200 25.0 661 100
# 200 25.0 661 150
# 200 25.0 661 200
# 200 25.0 661 250
# 200 25.0 661 300
# 200 25.0 661 350
# 200 25.0 661 400
# 200 25.0 661 450
# 200 25.0 661 500
# 200 25.0 661 550
# 200 25.0 661 600
# 200 25.0 661 650
# 200 26.0 900 0
# 200 26.0 900 50
# 200 26.0 900 100
# 200 26.0 900 150
# 200 26.0 900 200
# 200 26.0 900 250
# 200 26.0 900 300
# 200 26.0 900 350
# 200 26.0 900 400
# 200 26.0 900 450
# 200 26.0 900 500
# 200 26.0 900 550
# 200 26.0 900 600
# 200 26.0 900 650
# 200 26.0 900 700
# 200 26.0 900 750
# 200 26.0 900 800
# 200 26.0 900 850
# 200 27.0 843 0
# 200 27.0 843 50
# 200 27.0 843 100
# 200 27.0 843 150
# 200 27.0 843 200
# 200 27.0 843 250
# 200 27.0 843 300
# 200 27.0 843 350
# 200 27.0 843 400
# 200 27.0 843 450
# 200 27.0 843 500
# 200 27.0 843 550
# 200 27.0 843 600
# 200 27.0 843 650
# 200 27.0 843 700
# 200 27.0 843 750
# 200 27.0 843 800
# 200 28.0 646 0
# 200 28.0 646 50
# 200 28.0 646 100
# 200 28.0 646 150
# 200 28.0 646 200
# 200 28.0 646 250
# 200 28.0 646 300
# 200 28.0 646 350
# 200 28.0 646 400
# 200 28.0 646 450
# 200 28.0 646 500
# 200 28.0 646 550
# 200 28.0 646 600
# 200 29.0 537 0
# 200 29.0 537 50
# 200 29.0 537 100
# 200 29.0 537 150
# 200 29.0 537 200
# 200 29.0 537 250
# 200 29.0 537 300
# 200 29.0 537 350
# 200 29.0 537 400
# 200 29.0 537 450
# 200 29.0 537 500
# 200 30.0 542 0
# 200 30.0 542 50
# 200 30.0 542 100
# 200 30.0 542 150
# 200 30.0 542 200
# 200 30.0 542 250
# 200 30.0 542 300
# 200 30.0 542 350
# 200 30.0 542 400
# 200 30.0 542 450
# 200 30.0 542 500
# 200 31.0 585 0
# 200 31.0 585 50
# 200 31.0 585 100
# 200 31.0 585 150
# 200 31.0 585 200
# 200 31.0 585 250
# 200 31.0 585 300
# 200 31.0 585 350
# 200 31.0 585 400
# 200 31.0 585 450
# 200 31.0 585 500
# 200 31.0 585 550
# 200 32.0 651 0
# 200 32.0 651 50
# 200 32.0 651 100
# 200 32.0 651 150
# 200 32.0 651 200
# 200 32.0 651 250
# 200 32.0 651 300
# 200 32.0 651 350
# 200 32.0 651 400
# 200 32.0 651 450
# 200 32.0 651 500
# 200 32.0 651 550
# 200 32.0 651 600
# 200 32.0 651 650
# 200 33.0 414 0
# 200 33.0 414 50
# 200 33.0 414 100
# 200 33.0 414 150
# 200 33.0 414 200
# 200 33.0 414 250
# 200 33.0 414 300
# 200 33.0 414 350
# 200 33.0 414 400
# 200 34.0 741 0
# 200 34.0 741 50
# 200 34.0 741 100
# 200 34.0 741 150
# 200 34.0 741 200
# 200 34.0 741 250
# 200 34.0 741 300
# 200 34.0 741 350
# 200 34.0 741 400
# 200 34.0 741 450
# 200 34.0 741 500
# 200 34.0 741 550
# 200 34.0 741 600
# 200 34.0 741 650
# 200 34.0 741 700
# 200 35.0 474 0
# 200 35.0 474 50
# 200 35.0 474 100
# 200 35.0 474 150
# 200 35.0 474 200
# 200 35.0 474 250
# 200 35.0 474 300
# 200 35.0 474 350
# 200 35.0 474 400
# 200 35.0 474 450
# 200 36.0 863 0
# 200 36.0 863 50
# 200 36.0 863 100
# 200 36.0 863 150
# 200 36.0 863 200
# 200 36.0 863 250
# 200 36.0 863 300
# 200 36.0 863 350
# 200 36.0 863 400
# 200 36.0 863 450
# 200 36.0 863 500
# 200 36.0 863 550
# 200 36.0 863 600
# 200 36.0 863 650
# 200 36.0 863 700
# 200 36.0 863 750
# 200 36.0 863 800
# 200 36.0 863 850
# 200 37.0 910 0
# 200 37.0 910 50
# 200 37.0 910 100
# 200 37.0 910 150
# 200 37.0 910 200
# 200 37.0 910 250
# 200 37.0 910 300
# 200 37.0 910 350
# 200 37.0 910 400
# 200 37.0 910 450
# 200 37.0 910 500
# 200 37.0 910 550
# 200 37.0 910 600
# 200 37.0 910 650
# 200 37.0 910 700
# 200 37.0 910 750
# 200 37.0 910 800
# 200 37.0 910 850
# 200 37.0 910 900
# 200 38.0 629 0
# 200 38.0 629 50
# 200 38.0 629 100
# 200 38.0 629 150
# 200 38.0 629 200
# 200 38.0 629 250
# 200 38.0 629 300
# 200 38.0 629 350
# 200 38.0 629 400
# 200 38.0 629 450
# 200 38.0 629 500
# 200 38.0 629 550
# 200 38.0 629 600
# 200 39.0 466 0
# 200 39.0 466 50
# 200 39.0 466 100
# 200 39.0 466 150
# 200 39.0 466 200
# 200 39.0 466 250
# 200 39.0 466 300
# 200 39.0 466 350
# 200 39.0 466 400
# 200 39.0 466 450
# 200 40.0 703 0
# 200 40.0 703 50
# 200 40.0 703 100
# 200 40.0 703 150
# 200 40.0 703 200
# 200 40.0 703 250
# 200 40.0 703 300
# 200 40.0 703 350
# 200 40.0 703 400
# 200 40.0 703 450
# 200 40.0 703 500
# 200 40.0 703 550
# 200 40.0 703 600
# 200 40.0 703 650
# 200 40.0 703 700
# 200 41.0 1200 0
# 200 41.0 1200 50
# 200 41.0 1200 100
# 200 41.0 1200 150
# 200 41.0 1200 200
# 200 41.0 1200 250
# 200 41.0 1200 300
# 200 41.0 1200 350
# 200 41.0 1200 400
# 200 41.0 1200 450
# 200 41.0 1200 500
# 200 41.0 1200 550
# 200 41.0 1200 600
# 200 41.0 1200 650
# 200 41.0 1200 700
# 200 41.0 1200 750
# 200 41.0 1200 800
# 200 41.0 1200 850
# 200 41.0 1200 900
# 200 41.0 1200 950
# 200 42.0 875 0
# 200 42.0 875 50
# 200 42.0 875 100
# 200 42.0 875 150
# 200 42.0 875 200
# 200 42.0 875 250
# 200 42.0 875 300
# 200 42.0 875 350
# 200 42.0 875 400
# 200 42.0 875 450
# 200 42.0 875 500
# 200 42.0 875 550
# 200 42.0 875 600
# 200 42.0 875 650
# 200 42.0 875 700
# 200 42.0 875 750
# 200 42.0 875 800
# 200 42.0 875 850
# 200 43.0 423 0
# 200 43.0 423 50
# 200 43.0 423 100
# 200 43.0 423 150
# 200 43.0 423 200
# 200 43.0 423 250
# 200 43.0 423 300
# 200 43.0 423 350
# 200 43.0 423 400
# 200 44.0 1300 0
# 200 44.0 1300 50
# 200 44.0 1300 100
# 200 44.0 1300 150
# 200 44.0 1300 200
# 200 44.0 1300 250
# 200 44.0 1300 300
# 200 44.0 1300 350
# 200 44.0 1300 400
# 200 44.0 1300 450
# 200 44.0 1300 500
# 200 44.0 1300 550
# 200 44.0 1300 600
# 200 44.0 1300 650
# 200 44.0 1300 700
# 200 44.0 1300 750
# 200 44.0 1300 800
# 200 44.0 1300 850
# 200 44.0 1300 900
# 200 44.0 1300 950
# 200 45.0 427 0
# 200 45.0 427 50
# 200 45.0 427 100
# 200 45.0 427 150
# 200 45.0 427 200
# 200 45.0 427 250
# 200 45.0 427 300
# 200 45.0 427 350
# 200 45.0 427 400
# 200 46.0 885 0
# 200 46.0 885 50
# 200 46.0 885 100
# 200 46.0 885 150
# 200 46.0 885 200
# 200 46.0 885 250
# 200 46.0 885 300
# 200 46.0 885 350
# 200 46.0 885 400
# 200 46.0 885 450
# 200 46.0 885 500
# 200 46.0 885 550
# 200 46.0 885 600
# 200 46.0 885 650
# 200 46.0 885 700
# 200 46.0 885 750
# 200 46.0 885 800
# 200 46.0 885 850
# 200 47.0 1300 0
# 200 47.0 1300 50
# 200 47.0 1300 100
# 200 47.0 1300 150
# 200 47.0 1300 200
# 200 47.0 1300 250
# 200 47.0 1300 300
# 200 47.0 1300 350
# 200 47.0 1300 400
# 200 47.0 1300 450
# 200 47.0 1300 500
# 200 47.0 1300 550
# 200 47.0 1300 600
# 200 47.0 1300 650
# 200 47.0 1300 700
# 200 47.0 1300 750
# 200 47.0 1300 800
# 200 47.0 1300 850
# 200 47.0 1300 900
# 200 47.0 1300 950
# 200 48.0 950 0
# 200 48.0 950 50
# 200 48.0 950 100
# 200 48.0 950 150
# 200 48.0 950 200
# 200 48.0 950 250
# 200 48.0 950 300
# 200 48.0 950 350
# 200 48.0 950 400
# 200 48.0 950 450
# 200 48.0 950 500
# 200 48.0 950 550
# 200 48.0 950 600
# 200 48.0 950 650
# 200 48.0 950 700
# 200 48.0 950 750
# 200 48.0 950 800
# 200 48.0 950 850
# 200 48.0 950 900
# 200 49.0 1300 0
# 200 49.0 1300 50
# 200 49.0 1300 100
# 200 49.0 1300 150
# 200 49.0 1300 200
# 200 49.0 1300 250
# 200 49.0 1300 300
# 200 49.0 1300 350
# 200 49.0 1300 400
# 200 49.0 1300 450
# 200 49.0 1300 500
# 200 49.0 1300 550
# 200 49.0 1300 600
# 200 49.0 1300 650
# 200 49.0 1300 700
# 200 49.0 1300 750
# 200 49.0 1300 800
# 200 49.0 1300 850
# 200 49.0 1300 900
# 200 49.0 1300 950
# 200 50.0 422 0
# 200 50.0 422 50
# 200 50.0 422 100
# 200 50.0 422 150
# 200 50.0 422 200
# 200 50.0 422 250
# 200 50.0 422 300
# 200 50.0 422 350
# 200 50.0 422 400
# 200 51.0 428 0
# 200 51.0 428 50
# 200 51.0 428 100
# 200 51.0 428 150
# 200 51.0 428 200
# 200 51.0 428 250
# 200 51.0 428 300
# 200 51.0 428 350
# 200 51.0 428 400
# 200 52.0 486 0
# 200 52.0 486 50
# 200 52.0 486 100
# 200 52.0 486 150
# 200 52.0 486 200
# 200 52.0 486 250
# 200 52.0 486 300
# 200 52.0 486 350
# 200 52.0 486 400
# 200 52.0 486 450
# 200 53.0 970 0
# 200 53.0 970 50
# 200 53.0 970 100
# 200 53.0 970 150
# 200 53.0 970 200
# 200 53.0 970 250
# 200 53.0 970 300
# 200 53.0 970 350
# 200 53.0 970 400
# 200 53.0 970 450
# 200 53.0 970 500
# 200 53.0 970 550
# 200 53.0 970 600
# 200 53.0 970 650
# 200 53.0 970 700
# 200 53.0 970 750
# 200 53.0 970 800
# 200 53.0 970 850
# 200 53.0 970 900
# 200 53.0 970 950
# 200 54.0 1300 0
# 200 54.0 1300 50
# 200 54.0 1300 100
# 200 54.0 1300 150
# 200 54.0 1300 200
# 200 54.0 1300 250
# 200 54.0 1300 300
# 200 54.0 1300 350
# 200 54.0 1300 400
# 200 54.0 1300 450
# 200 54.0 1300 500
# 200 54.0 1300 550
# 200 54.0 1300 600
# 200 54.0 1300 650
# 200 54.0 1300 700
# 200 54.0 1300 750
# 200 54.0 1300 800
# 200 54.0 1300 850
# 200 54.0 1300 900
# 200 54.0 1300 950
# 200 55.0 1100 0
# 200 55.0 1100 50
# 200 55.0 1100 100
# 200 55.0 1100 150
# 200 55.0 1100 200
# 200 55.0 1100 250
# 200 55.0 1100 300
# 200 55.0 1100 350
# 200 55.0 1100 400
# 200 55.0 1100 450
# 200 55.0 1100 500
# 200 55.0 1100 550
# 200 55.0 1100 600
# 200 55.0 1100 650
# 200 55.0 1100 700
# 200 55.0 1100 750
# 200 55.0 1100 800
# 200 55.0 1100 850
# 200 55.0 1100 900
# 200 55.0 1100 950
# 200 56.0 1300 0
# 200 56.0 1300 50
# 200 56.0 1300 100
# 200 56.0 1300 150
# 200 56.0 1300 200
# 200 56.0 1300 250
# 200 56.0 1300 300
# 200 56.0 1300 350
# 200 56.0 1300 400
# 200 56.0 1300 450
# 200 56.0 1300 500
# 200 56.0 1300 550
# 200 56.0 1300 600
# 200 56.0 1300 650
# 200 56.0 1300 700
# 200 56.0 1300 750
# 200 56.0 1300 800
# 200 56.0 1300 850
# 200 56.0 1300 900
# 200 56.0 1300 950
# 200 57.0 1300 0
# 200 57.0 1300 50
# 200 57.0 1300 100
# 200 57.0 1300 150
# 200 57.0 1300 200
# 200 57.0 1300 250
# 200 57.0 1300 300
# 200 57.0 1300 350
# 200 57.0 1300 400
# 200 57.0 1300 450
# 200 57.0 1300 500
# 200 57.0 1300 550
# 200 57.0 1300 600
# 200 57.0 1300 650
# 200 57.0 1300 700
# 200 57.0 1300 750
# 200 57.0 1300 800
# 200 57.0 1300 850
# 200 57.0 1300 900
# 200 57.0 1300 950
# 200 58.0 766 0
# 200 58.0 766 50
# 200 58.0 766 100
# 200 58.0 766 150
# 200 58.0 766 200
# 200 58.0 766 250
# 200 58.0 766 300
# 200 58.0 766 350
# 200 58.0 766 400
# 200 58.0 766 450
# 200 58.0 766 500
# 200 58.0 766 550
# 200 58.0 766 600
# 200 58.0 766 650
# 200 58.0 766 700
# 200 58.0 766 750
# 200 59.0 1300 0
# 200 59.0 1300 50
# 200 59.0 1300 100
# 200 59.0 1300 150
# 200 59.0 1300 200
# 200 59.0 1300 250
# 200 59.0 1300 300
# 200 59.0 1300 350
# 200 59.0 1300 400
# 200 59.0 1300 450
# 200 59.0 1300 500
# 200 59.0 1300 550
# 200 59.0 1300 600
# 200 59.0 1300 650
# 200 59.0 1300 700
# 200 59.0 1300 750
# 200 59.0 1300 800
# 200 59.0 1300 850
# 200 59.0 1300 900
# 200 59.0 1300 950
# 200 60.0 1300 0
# 200 60.0 1300 50
# 200 60.0 1300 100
# 200 60.0 1300 150
# 200 60.0 1300 200
# 200 60.0 1300 250
# 200 60.0 1300 300
# 200 60.0 1300 350
# 200 60.0 1300 400
# 200 60.0 1300 450
# 200 60.0 1300 500
# 200 60.0 1300 550
# 200 60.0 1300 600
# 200 60.0 1300 650
# 200 60.0 1300 700
# 200 60.0 1300 750
# 200 60.0 1300 800
# 200 60.0 1300 850
# 200 60.0 1300 900
# 200 60.0 1300 950
# 200 61.0 436 0
# 200 61.0 436 50
# 200 61.0 436 100
# 200 61.0 436 150
# 200 61.0 436 200
# 200 61.0 436 250
# 200 61.0 436 300
# 200 61.0 436 350
# 200 61.0 436 400
# 200 62.0 1300 0
# 200 62.0 1300 50
# 200 62.0 1300 100
# 200 62.0 1300 150
# 200 62.0 1300 200
# 200 62.0 1300 250
# 200 62.0 1300 300
# 200 62.0 1300 350
# 200 62.0 1300 400
# 200 62.0 1300 450
# 200 62.0 1300 500
# 200 62.0 1300 550
# 200 62.0 1300 600
# 200 62.0 1300 650
# 200 62.0 1300 700
# 200 62.0 1300 750
# 200 62.0 1300 800
# 200 62.0 1300 850
# 200 62.0 1300 900
# 200 62.0 1300 950
# 200 63.0 488 0
# 200 63.0 488 50
# 200 63.0 488 100
# 200 63.0 488 150
# 200 63.0 488 200
# 200 63.0 488 250
# 200 63.0 488 300
# 200 63.0 488 350
# 200 63.0 488 400
# 200 63.0 488 450
# 200 64.0 1200 0
# 200 64.0 1200 50
# 200 64.0 1200 100
# 200 64.0 1200 150
# 200 64.0 1200 200
# 200 64.0 1200 250
# 200 64.0 1200 300
# 200 64.0 1200 350
# 200 64.0 1200 400
# 200 64.0 1200 450
# 200 64.0 1200 500
# 200 64.0 1200 550
# 200 64.0 1200 600
# 200 64.0 1200 650
# 200 64.0 1200 700
# 200 64.0 1200 750
# 200 64.0 1200 800
# 200 64.0 1200 850
# 200 64.0 1200 900
# 200 64.0 1200 950
# 200 65.0 1100 0
# 200 65.0 1100 50
# 200 65.0 1100 100
# 200 65.0 1100 150
# 200 65.0 1100 200
# 200 65.0 1100 250
# 200 65.0 1100 300
# 200 65.0 1100 350
# 200 65.0 1100 400
# 200 65.0 1100 450
# 200 65.0 1100 500
# 200 65.0 1100 550
# 200 65.0 1100 600
# 200 65.0 1100 650
# 200 65.0 1100 700
# 200 65.0 1100 750
# 200 65.0 1100 800
# 200 65.0 1100 850
# 200 65.0 1100 900
# 200 65.0 1100 950
# 200 66.0 1200 0
# 200 66.0 1200 50
# 200 66.0 1200 100
# 200 66.0 1200 150
# 200 66.0 1200 200
# 200 66.0 1200 250
# 200 66.0 1200 300
# 200 66.0 1200 350
# 200 66.0 1200 400
# 200 66.0 1200 450
# 200 66.0 1200 500
# 200 66.0 1200 550
# 200 66.0 1200 600
# 200 66.0 1200 650
# 200 66.0 1200 700
# 200 66.0 1200 750
# 200 66.0 1200 800
# 200 66.0 1200 850
# 200 66.0 1200 900
# 200 66.0 1200 950
# 200 67.0 373 0
# 200 67.0 373 50
# 200 67.0 373 100
# 200 67.0 373 150
# 200 67.0 373 200
# 200 67.0 373 250
# 200 67.0 373 300
# 200 67.0 373 350
# 200 68.0 1100 0
# 200 68.0 1100 50
# 200 68.0 1100 100
# 200 68.0 1100 150
# 200 68.0 1100 200
# 200 68.0 1100 250
# 200 68.0 1100 300
# 200 68.0 1100 350
# 200 68.0 1100 400
# 200 68.0 1100 450
# 200 68.0 1100 500
# 200 68.0 1100 550
# 200 68.0 1100 600
# 200 68.0 1100 650
# 200 68.0 1100 700
# 200 68.0 1100 750
# 200 68.0 1100 800
# 200 68.0 1100 850
# 200 68.0 1100 900
# 200 68.0 1100 950
# 200 69.0 378 0
# 200 69.0 378 50
# 200 69.0 378 100
# 200 69.0 378 150
# 200 69.0 378 200
# 200 69.0 378 250
# 200 69.0 378 300
# 200 69.0 378 350
# 200 70.0 439 0
# 200 70.0 439 50
# 200 70.0 439 100
# 200 70.0 439 150
# 200 70.0 439 200
# 200 70.0 439 250
# 200 70.0 439 300
# 200 70.0 439 350
# 200 70.0 439 400
# 200 71.0 361 0
# 200 71.0 361 50
# 200 71.0 361 100
# 200 71.0 361 150
# 200 71.0 361 200
# 200 71.0 361 250
# 200 71.0 361 300
# 200 71.0 361 350
# 200 72.0 1200 0
# 200 72.0 1200 50
# 200 72.0 1200 100
# 200 72.0 1200 150
# 200 72.0 1200 200
# 200 72.0 1200 250
# 200 72.0 1200 300
# 200 72.0 1200 350
# 200 72.0 1200 400
# 200 72.0 1200 450
# 200 72.0 1200 500
# 200 72.0 1200 550
# 200 72.0 1200 600
# 200 72.0 1200 650
# 200 72.0 1200 700
# 200 72.0 1200 750
# 200 72.0 1200 800
# 200 72.0 1200 850
# 200 72.0 1200 900
# 200 72.0 1200 950
# 200 73.0 668 0
# 200 73.0 668 50
# 200 73.0 668 100
# 200 73.0 668 150
# 200 73.0 668 200
# 200 73.0 668 250
# 200 73.0 668 300
# 200 73.0 668 350
# 200 73.0 668 400
# 200 73.0 668 450
# 200 73.0 668 500
# 200 73.0 668 550
# 200 73.0 668 600
# 200 73.0 668 650
# 200 74.0 1000 0
# 200 74.0 1000 50
# 200 74.0 1000 100
# 200 74.0 1000 150
# 200 74.0 1000 200
# 200 74.0 1000 250
# 200 74.0 1000 300
# 200 74.0 1000 350
# 200 74.0 1000 400
# 200 74.0 1000 450
# 200 74.0 1000 500
# 200 74.0 1000 550
# 200 74.0 1000 600
# 200 74.0 1000 650
# 200 74.0 1000 700
# 200 74.0 1000 750
# 200 74.0 1000 800
# 200 74.0 1000 850
# 200 74.0 1000 900
# 200 74.0 1000 950
# 200 75.0 1100 0
# 200 75.0 1100 50
# 200 75.0 1100 100
# 200 75.0 1100 150
# 200 75.0 1100 200
# 200 75.0 1100 250
# 200 75.0 1100 300
# 200 75.0 1100 350
# 200 75.0 1100 400
# 200 75.0 1100 450
# 200 75.0 1100 500
# 200 75.0 1100 550
# 200 75.0 1100 600
# 200 75.0 1100 650
# 200 75.0 1100 700
# 200 75.0 1100 750
# 200 75.0 1100 800
# 200 75.0 1100 850
# 200 75.0 1100 900
# 200 75.0 1100 950
# 200 76.0 285 0
# 200 76.0 285 50
# 200 76.0 285 100
# 200 76.0 285 150
# 200 76.0 285 200
# 200 76.0 285 250
# 200 77.0 962 0
# 200 77.0 962 50
# 200 77.0 962 100
# 200 77.0 962 150
# 200 77.0 962 200
# 200 77.0 962 250
# 200 77.0 962 300
# 200 77.0 962 350
# 200 77.0 962 400
# 200 77.0 962 450
# 200 77.0 962 500
# 200 77.0 962 550
# 200 77.0 962 600
# 200 77.0 962 650
# 200 77.0 962 700
# 200 77.0 962 750
# 200 77.0 962 800
# 200 77.0 962 850
# 200 77.0 962 900
# 200 77.0 962 950
# 200 78.0 622 0
# 200 78.0 622 50
# 200 78.0 622 100
# 200 78.0 622 150
# 200 78.0 622 200
# 200 78.0 622 250
# 200 78.0 622 300
# 200 78.0 622 350
# 200 78.0 622 400
# 200 78.0 622 450
# 200 78.0 622 500
# 200 78.0 622 550
# 200 78.0 622 600
# 200 79.0 1100 0
# 200 79.0 1100 50
# 200 79.0 1100 100
# 200 79.0 1100 150
# 200 79.0 1100 200
# 200 79.0 1100 250
# 200 79.0 1100 300
# 200 79.0 1100 350
# 200 79.0 1100 400
# 200 79.0 1100 450
# 200 79.0 1100 500
# 200 79.0 1100 550
# 200 79.0 1100 600
# 200 79.0 1100 650
# 200 79.0 1100 700
# 200 79.0 1100 750
# 200 79.0 1100 800
# 200 79.0 1100 850
# 200 79.0 1100 900
# 200 79.0 1100 950
# 200 80.0 276 0
# 200 80.0 276 50
# 200 80.0 276 100
# 200 80.0 276 150
# 200 80.0 276 200
# 200 80.0 276 250
# 200 81.0 1000 0
# 200 81.0 1000 50
# 200 81.0 1000 100
# 200 81.0 1000 150
# 200 81.0 1000 200
# 200 81.0 1000 250
# 200 81.0 1000 300
# 200 81.0 1000 350
# 200 81.0 1000 400
# 200 81.0 1000 450
# 200 81.0 1000 500
# 200 81.0 1000 550
# 200 81.0 1000 600
# 200 81.0 1000 650
# 200 81.0 1000 700
# 200 81.0 1000 750
# 200 81.0 1000 800
# 200 81.0 1000 850
# 200 81.0 1000 900
# 200 81.0 1000 950
# 200 82.0 991 0
# 200 82.0 991 50
# 200 82.0 991 100
# 200 82.0 991 150
# 200 82.0 991 200
# 200 82.0 991 250
# 200 82.0 991 300
# 200 82.0 991 350
# 200 82.0 991 400
# 200 82.0 991 450
# 200 82.0 991 500
# 200 82.0 991 550
# 200 82.0 991 600
# 200 82.0 991 650
# 200 82.0 991 700
# 200 82.0 991 750
# 200 82.0 991 800
# 200 82.0 991 850
# 200 82.0 991 900
# 200 82.0 991 950
# 200 83.0 996 0
# 200 83.0 996 50
# 200 83.0 996 100
# 200 83.0 996 150
# 200 83.0 996 200
# 200 83.0 996 250
# 200 83.0 996 300
# 200 83.0 996 350
# 200 83.0 996 400
# 200 83.0 996 450
# 200 83.0 996 500
# 200 83.0 996 550
# 200 83.0 996 600
# 200 83.0 996 650
# 200 83.0 996 700
# 200 83.0 996 750
# 200 83.0 996 800
# 200 83.0 996 850
# 200 83.0 996 900
# 200 83.0 996 950
# 200 84.0 909 0
# 200 84.0 909 50
# 200 84.0 909 100
# 200 84.0 909 150
# 200 84.0 909 200
# 200 84.0 909 250
# 200 84.0 909 300
# 200 84.0 909 350
# 200 84.0 909 400
# 200 84.0 909 450
# 200 84.0 909 500
# 200 84.0 909 550
# 200 84.0 909 600
# 200 84.0 909 650
# 200 84.0 909 700
# 200 84.0 909 750
# 200 84.0 909 800
# 200 84.0 909 850
# 200 84.0 909 900
# 200 85.0 916 0
# 200 85.0 916 50
# 200 85.0 916 100
# 200 85.0 916 150
# 200 85.0 916 200
# 200 85.0 916 250
# 200 85.0 916 300
# 200 85.0 916 350
# 200 85.0 916 400
# 200 85.0 916 450
# 200 85.0 916 500
# 200 85.0 916 550
# 200 85.0 916 600
# 200 85.0 916 650
# 200 85.0 916 700
# 200 85.0 916 750
# 200 85.0 916 800
# 200 85.0 916 850
# 200 85.0 916 900
# 200 86.0 619 0
# 200 86.0 619 50
# 200 86.0 619 100
# 200 86.0 619 150
# 200 86.0 619 200
# 200 86.0 619 250
# 200 86.0 619 300
# 200 86.0 619 350
# 200 86.0 619 400
# 200 86.0 619 450
# 200 86.0 619 500
# 200 86.0 619 550
# 200 86.0 619 600

# %%
yelp_search_coord(37.749044, -122.418166)
# Out:
# 200 0 833 0
# 200 0 833 50
# 200 0 833 100
# 200 0 833 150
# 200 0 833 200
# 200 0 833 250
# 200 0 833 300
# 200 0 833 350
# 200 0 833 400
# 200 0 833 450
# 200 0 833 500
# 200 0 833 550
# 200 0 833 600
# 200 0 833 650
# 200 0 833 700
# 200 0 833 750
# 200 0 833 800

# %% [markdown]
# ## Reading in

# %%
json_per_line = []
with open(REF_PATH + 'yelp_api_json.json', 'r') as f:
    for line in f.readlines():
        json_per_line.append(json.loads(line.strip()))

# %%
biz_j['businesses']
# Out:
# [{'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'coordinates': {'latitude': 37.75265, 'longitude': -122.41812},
#   'display_phone': '(415) 824-7877',
#   'distance': 401.419500708758,
#   'id': 'el-farolito-san-francisco-2',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OPnKCvgBR2-lQ1-yahrpiA/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2779 Mission St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['2779 Mission St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'El Farolito',
#   'phone': '+14158247877',
#   'price': '$',
#   'rating': 4.0,
#   'review_count': 4303,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/el-farolito-san-francisco-2?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'coordinates': {'latitude': 37.750883, 'longitude': -122.418123},
#   'display_phone': '(415) 285-7117',
#   'distance': 204.52218838114598,
#   'id': 'la-taqueria-san-francisco-2',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Vg14X7hOLoMyVlk3iAQ4ng/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2889 Mission St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['2889 Mission St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'La Taqueria',
#   'phone': '+14152857117',
#   'price': '$',
#   'rating': 4.0,
#   'review_count': 3313,
#   'transactions': ['restaurant_reservation'],
#   'url': 'https://www.yelp.com/biz/la-taqueria-san-francisco-2?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'coordinates': {'latitude': 37.7614250022004,
#    'longitude': -122.424051321456},
#   'display_phone': '(415) 487-2600',
#   'distance': 1470.720423343962,
#   'id': 'tartine-bakery-and-cafe-san-francisco',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vTLu8G86IqIazm7BRqIH4g/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '600 Guerrero St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['600 Guerrero St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'Tartine Bakery & Cafe',
#   'phone': '+14154872600',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 7027,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/tartine-bakery-and-cafe-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'coordinates': {'latitude': 37.752397102831, 'longitude': -122.41426366546},
#   'display_phone': '(415) 875-9370',
#   'distance': 506.68289728558995,
#   'id': 'philz-coffee-san-francisco',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/mGZVAE9mrLTQ67s1FuGI1g/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '3101 24th St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['3101 24th St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'Philz Coffee',
#   'phone': '+14158759370',
#   'price': '$',
#   'rating': 4.5,
#   'review_count': 1587,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/philz-coffee-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'coordinates': {'latitude': 37.75637, 'longitude': -122.41925},
#   'display_phone': '(415) 648-7600',
#   'distance': 824.440775052404,
#   'id': 'foreign-cinema-san-francisco',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Ynyfg9pp8v8UaTtFFOh98A/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2534 Mission St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['2534 Mission St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'Foreign Cinema',
#   'phone': '+14156487600',
#   'price': '$$$',
#   'rating': 4.0,
#   'review_count': 4337,
#   'transactions': ['restaurant_reservation'],
#   'url': 'https://www.yelp.com/biz/foreign-cinema-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'coordinates': {'latitude': 37.753868, 'longitude': -122.420636},
#   'display_phone': '(415) 695-1199',
#   'distance': 578.6944168788899,
#   'id': 'beretta-san-francisco',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Au1vrkX9VqUtKfzI3QMkdA/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1199 Valencia St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['1199 Valencia St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'Beretta',
#   'phone': '+14156951199',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 3211,
#   'transactions': ['restaurant_reservation'],
#   'url': 'https://www.yelp.com/biz/beretta-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'coordinates': {'latitude': 37.750552, 'longitude': -122.418153},
#   'display_phone': '(415) 282-1500',
#   'distance': 167.68565879117799,
#   'id': 'mission-pie-san-francisco',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9TZS6ZIEPkOToBpLxCgUSg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2901 Mission St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['2901 Mission St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'Mission Pie',
#   'phone': '+14152821500',
#   'price': '$',
#   'rating': 4.0,
#   'review_count': 1607,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/mission-pie-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'latin', 'title': 'Latin American'},
#    {'alias': 'peruvian', 'title': 'Peruvian'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'coordinates': {'latitude': 37.7570666079255,
#    'longitude': -122.416596234642},
#   'display_phone': '(415) 821-2134',
#   'distance': 902.684597370924,
#   'id': 'limón-rotisserie-san-francisco-3',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wvbMWakjpf0c-0QeucFl9Q/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1001 S Van Ness Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['1001 S Van Ness Ave', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'Limón Rotisserie',
#   'phone': '+14158212134',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 2895,
#   'transactions': ['restaurant_reservation', 'pickup'],
#   'url': 'https://www.yelp.com/biz/lim%C3%B3n-rotisserie-san-francisco-3?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'arabian', 'title': 'Arabian'}],
#   'coordinates': {'latitude': 37.7494333410663,
#    'longitude': -122.418358325958},
#   'display_phone': '(415) 642-5958',
#   'distance': 46.477866981596,
#   'id': 'old-jerusalem-restaurant-san-francisco',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/-7bTRPJR2SCXbtjCk1_pCg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2976 Mission St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['2976 Mission St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'Old Jerusalem Restaurant',
#   'phone': '+14156425958',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 916,
#   'transactions': ['pickup', 'delivery'],
#   'url': 'https://www.yelp.com/biz/old-jerusalem-restaurant-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'argentine', 'title': 'Argentine'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'coordinates': {'latitude': 37.7566647, 'longitude': -122.4190863},
#   'display_phone': '(415) 550-6970',
#   'distance': 851.2362269896261,
#   'id': 'lolinda-san-francisco',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/wYzB4595TuYesGnyUt9lPw/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '2518 Mission St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['2518 Mission St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'Lolinda',
#   'phone': '+14155506970',
#   'price': '$$$',
#   'rating': 4.0,
#   'review_count': 1611,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/lolinda-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'parks', 'title': 'Parks'},
#    {'alias': 'playgrounds', 'title': 'Playgrounds'},
#    {'alias': 'basketballcourts', 'title': 'Basketball Courts'}],
#   'coordinates': {'latitude': 37.759764, 'longitude': -122.427052},
#   'display_phone': '(415) 831-2700',
#   'distance': 1425.195331508556,
#   'id': 'mission-dolores-park-san-francisco',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/9m6qOWYztlV8jOR9z1u11g/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '19th & Dolores St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['19th & Dolores St', 'San Francisco, CA 94114'],
#    'state': 'CA',
#    'zip_code': '94114'},
#   'name': 'Mission Dolores Park',
#   'phone': '+14158312700',
#   'rating': 4.5,
#   'review_count': 1374,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/mission-dolores-park-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'coordinates': {'latitude': 37.7573462, 'longitude': -122.4214034},
#   'display_phone': '(415) 643-5656',
#   'distance': 966.041768482516,
#   'id': 'loló-san-francisco-4',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-_hqewRYasro3NpC-v4Fug/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '974 Valencia St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['974 Valencia St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'Loló',
#   'phone': '+14156435656',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 1755,
#   'transactions': ['restaurant_reservation'],
#   'url': 'https://www.yelp.com/biz/lol%C3%B3-san-francisco-4?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'southern', 'title': 'Southern'},
#    {'alias': 'cajun', 'title': 'Cajun/Creole'}],
#   'coordinates': {'latitude': 37.74372, 'longitude': -122.42197},
#   'display_phone': '(415) 695-7800',
#   'distance': 673.860518820898,
#   'id': 'the-front-porch-san-francisco',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/WzTsLLarSYv5LgT4k73__g/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '65A 29th St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['65A 29th St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'The Front Porch',
#   'phone': '+14156957800',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 2412,
#   'transactions': ['restaurant_reservation'],
#   'url': 'https://www.yelp.com/biz/the-front-porch-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'coordinates': {'latitude': 37.74523, 'longitude': -122.42033},
#   'display_phone': '(415) 282-6777',
#   'distance': 471.95877080341995,
#   'id': 'blue-plate-san-francisco',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5iaI4aBsGYRaaRE1V4e8-w/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '3218 Mission St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['3218 Mission St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'Blue Plate',
#   'phone': '+14152826777',
#   'price': '$$$',
#   'rating': 4.0,
#   'review_count': 1299,
#   'transactions': ['pickup', 'delivery'],
#   'url': 'https://www.yelp.com/biz/blue-plate-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'british', 'title': 'British'},
#    {'alias': 'tea', 'title': 'Tea Rooms'}],
#   'coordinates': {'latitude': 37.74919, 'longitude': -122.42689},
#   'display_phone': '(415) 648-5895',
#   'distance': 781.800181995724,
#   'id': 'lovejoys-tea-room-san-francisco',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aQXA-PXoa77e-Jp--CYMaQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1351 Church St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['1351 Church St', 'San Francisco, CA 94114'],
#    'state': 'CA',
#    'zip_code': '94114'},
#   'name': "Lovejoy's Tea Room",
#   'phone': '+14156485895',
#   'price': '$$',
#   'rating': 4.5,
#   'review_count': 1083,
#   'transactions': ['restaurant_reservation'],
#   'url': 'https://www.yelp.com/biz/lovejoys-tea-room-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'coordinates': {'latitude': 37.75194, 'longitude': -122.42094},
#   'display_phone': '(415) 970-8815',
#   'distance': 412.101796870942,
#   'id': 'papalote-mexican-grill-san-francisco',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/n3j80kX1x8zYJUfQtscf8g/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '3409 24th St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['3409 24th St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'Papalote Mexican Grill',
#   'phone': '+14159708815',
#   'price': '$$',
#   'rating': 3.5,
#   'review_count': 2131,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/papalote-mexican-grill-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'mini_golf', 'title': 'Mini Golf'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'coordinates': {'latitude': 37.7557019908942,
#    'longitude': -122.416826814485},
#   'display_phone': '(415) 341-1080',
#   'distance': 749.637707652626,
#   'id': 'urban-putt-san-francisco',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/X4eBwbKxz0REM9bNtFBgSg/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '1096 S Van Ness Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['1096 S Van Ness Ave', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'Urban Putt',
#   'phone': '+14153411080',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 1038,
#   'transactions': ['pickup', 'restaurant_reservation'],
#   'url': 'https://www.yelp.com/biz/urban-putt-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#   'coordinates': {'latitude': 37.747, 'longitude': -122.41865},
#   'display_phone': '(415) 368-3802',
#   'distance': 230.63734429785197,
#   'id': 'coffeeshop-san-francisco',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/buGWN2vnsJyUcDST9wsFTQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '3139 Mission St',
#    'address2': '',
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['3139 Mission St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'CoffeeShop',
#   'phone': '+14153683802',
#   'price': '$$',
#   'rating': 4.5,
#   'review_count': 308,
#   'transactions': [],
#   'url': 'https://www.yelp.com/biz/coffeeshop-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#   'coordinates': {'latitude': 37.7570921927691,
#    'longitude': -122.421059310436},
#   'display_phone': '(415) 642-3672',
#   'distance': 927.9949060992959,
#   'id': 'dosa-on-valencia-san-francisco',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JhTS8_OJrQOsF7R-j9UkIw/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '995 Valencia St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['995 Valencia St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'DOSA on Valencia',
#   'phone': '+14156423672',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 2148,
#   'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#   'url': 'https://www.yelp.com/biz/dosa-on-valencia-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'},
#  {'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'coordinates': {'latitude': 37.76131, 'longitude': -122.42431},
#   'display_phone': '(415) 437-6800',
#   'distance': 1474.006371824754,
#   'id': 'pizzeria-delfina-san-francisco-san-francisco',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/mXfuUNiaoGaeg7ra4IgcJQ/o.jpg',
#   'is_closed': False,
#   'location': {'address1': '3621 18th St',
#    'address2': None,
#    'address3': '',
#    'city': 'San Francisco',
#    'country': 'US',
#    'display_address': ['3621 18th St', 'San Francisco, CA 94110'],
#    'state': 'CA',
#    'zip_code': '94110'},
#   'name': 'Pizzeria Delfina - San Francisco',
#   'phone': '+14154376800',
#   'price': '$$',
#   'rating': 4.0,
#   'review_count': 2185,
#   'transactions': ['restaurant_reservation'],
#   'url': 'https://www.yelp.com/biz/pizzeria-delfina-san-francisco-san-francisco?adjust_creative=JjtQ1txoSd69pSwUPsWxcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=JjtQ1txoSd69pSwUPsWxcA'}]

# %%
# Out:
# 6800

# %%
token.json()
# Out:
# {'access_token': 'e1eQ6CdDkrsPtzERZcm_YUHAyMBpl7XcSAgWFuvOrfofXjCygky4-AIICmDSRYpYqjtChJTJv2084_6gACmJko5vrW_TZiEcoTRlnC3BeoEdcXh6N6p2YbaLJI2HWnYx',
#  'expires_in': 628649819,
#  'token_type': 'Bearer'}
