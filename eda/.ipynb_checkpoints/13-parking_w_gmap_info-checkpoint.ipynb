# %%
import pandas as pd
import sys
import os
import json
sys.path.append('../')

# %%
df_parking = pd.read_csv('/Users/timlee/data/sf_parking/parkingrecords.csv')
ll_ids = pd.DataFrame(df_parking.groupby(['lat','lon']).size().reset_index())
ll_ids.columns = ['lat','lon','pid']
ll_ids['pid']= ll_ids.index
df_parking = df_parking.merge(ll_ids, how='left', on =['lat','lon'])

# %%
def gpsaddr_extract_json(one_addr):
    one_addr_details = {}
    one_addr_details['related_addr']  = []
    for item in one_addr:
        for subitem in item['address_components']:
            if subitem['types'] == ['street_number']:
                one_addr_details['street_no'] = subitem['long_name']
            if subitem['types'] == ['route']:
                one_addr_details['street_name'] = subitem['long_name']
            if 'neighborhood' in subitem['types']:
                one_addr_details['neighborhood'] = subitem['short_name']
            if 'postal_code' in subitem['types']:
                one_addr_details['zipcode'] = subitem['short_name']            
        if ('political' not in item['types']) and ('postal_code' not in item['types']):
            one_addr_details['related_addr'].append([item['formatted_address'],item['types']])
    if len(one_addr_details['related_addr']) > 1:
        one_addr_details['address_tags'] = [ x[1] for x in one_addr_details['related_addr'][1:]]
    return one_addr_details

# %%
search_dir = '../ref_data/gmaps_json/'
addr_collection = []
for fl in os.listdir(search_dir):
    if ('parking_json' in fl) and (fl != 'parking_json_0.json') :
        print(fl)
        with open(search_dir + fl,'r') as f:
            samp = f.read()
            samp = samp.replace('}{"lat','}\n{"lat')
            lines = samp.split('\n')
            jsons = [json.loads(ln) for ln in lines]            
            
        for jsn in jsons:
            lat = jsn['lat']
            lng = jsn['lng']
            one_addr_details = gpsaddr_extract_json(jsn['data'])
            one_addr_details['orig_lat'] = float(lat)
            one_addr_details['orig_lng'] = float(lng)
            one_addr_details['Search_GPS'] = lat+','+lng
            addr_collection.append(one_addr_details)
        print(len(addr_collection))
# Out:
# parking_json_21200.json
# 100
# parking_json_27100.json
# 200
# parking_json_20000.json
# 300
# parking_json_26300.json
# 400
# parking_json_18100.json
# 500
# parking_json_23600.json
# 600
# parking_json_9300.json
# 700
# parking_json_25500.json
# 800
# parking_json_22800.json
# 900
# parking_json_25900.json
# 1000
# parking_json_22400.json
# 1100
# parking_json_19300.json
# 1200
# parking_json_8100.json
# 1300
# parking_json_24700.json
# 1400
# parking_json_5600.json
# 1500
# parking_json_12700.json
# 1600
# parking_json_14400.json
# 1700
# parking_json_3500.json
# 1800
# parking_json_13900.json
# 1900
# parking_json_4800.json
# 2000
# parking_json_3900.json
# 2100
# parking_json_14800.json
# 2200
# parking_json_4400.json
# 2300
# parking_json_13500.json
# 2400
# parking_json_15600.json
# 2500
# parking_json_2700.json
# 2600
# parking_json_10300.json
# 2700
# parking_json_7200.json
# 2800
# parking_json_1100.json
# 2900
# parking_json_16000.json
# 3000
# parking_json_500.json
# 3100
# parking_json_900.json
# 3200
# parking_json_11100.json
# 3300
# parking_json_6000.json
# 3400
# parking_json_17200.json
# 3500
# parking_json_2500.json
# 3600
# parking_json_15400.json
# 3700
# parking_json_19400.json
# 22420
# parking_json_22300.json
# 22520
# parking_json_24000.json
# 22620
# parking_json_8600.json
# 22720
# parking_json_12000.json
# 22820
# parking_json_5100.json
# 22920
# parking_json_3200.json
# 23020
# parking_json_14300.json
# 23120
# parking_json_13200.json
# 23220
# parking_json_4300.json
# 23320
# parking_json_2000.json
# 23420
# parking_json_15100.json
# 23520
# parking_json_17900.json
# 23620
# parking_json_7500.json
# 23720
# parking_json_10400.json
# 23820
# parking_json_16700.json
# 23920
# parking_json_1600.json
# 24020
# parking_json_200.json
# 24120
# parking_json_6700.json
# 24220
# parking_json_11600.json
# 24320
# parking_json_17500.json
# 24420
# parking_json_10800.json
# 24520
# parking_json_7900.json
# 24620
# parking_json_15300.json
# 24720
# parking_json_2200.json
# 24820
# parking_json_4100.json
# 24920
# parking_json_13000.json
# 25020
# parking_json_14100.json
# 25120
# parking_json_3000.json
# 25220
# parking_json_5300.json
# 25320
# parking_json_12200.json
# 25420
# parking_json_17700.json
# 25520
# parking_json_16900.json
# 25620
# parking_json_1800.json
# 25720
# parking_json_11400.json
# 25820
# parking_json_6500.json
# 25920
# parking_json_1400.json
# 26020
# parking_json_16500.json
# 26120
# parking_json_6900.json
# 26220
# parking_json_11800.json
# 26320
# parking_json_10600.json
# 26420
# parking_json_7700.json
# 26520
# parking_json_26600.json
# 26620
# parking_json_27800.json
# 26720
# parking_json_20500.json
# 26820
# parking_json_27400.json
# 26920
# parking_json_20900.json
# 27020
# parking_json_21700.json
# 27120
# parking_json_8400.json
# 27220
# parking_json_24200.json
# 27320
# parking_json_18800.json
# 27420
# parking_json_19600.json
# 27520
# parking_json_22100.json
# 27620
# parking_json_9600.json
# 27720
# parking_json_25000.json
# 27820
# parking_json_8800.json
# 27920
# parking_json_23300.json
# 28020
# parking_json_18400.json
# 28120

# %%
df = pd.DataFrame(addr_collection)
df.loc[df['address_tags'].isna()==False,'address_tags'] = df.loc[df['address_tags'].isna()==False,'address_tags'].map(lambda x : ','.join(x[0]))
df['related_addr'] = df['related_addr'].astype(str)
df.to_feather('../ref_data/gmaps_df_parking.feather')

# %%
parking_gps = df.copy()

# %%
parking_gps.shape
# Out:
# (28211, 9)

# %%
parking_gps.head()
# Out:
#               Search_GPS                                       address_tags  \
# 0  37.789004,-122.417333                                                NaN
# 1  37.789005,-122.422216  establishment,general_contractor,local_governm...
# 2  37.789005,-122.409838                                     street_address
# 3  37.789005,-122.402346  bus_station,establishment,point_of_interest,tr...
# 4  37.789007,-122.434913  bus_station,establishment,point_of_interest,tr...
#
#          neighborhood   orig_lat    orig_lng  \
# 0      Lower Nob Hill  37.789004 -122.417333
# 1    Western Addition  37.789005 -122.422216
# 2      Lower Nob Hill  37.789005 -122.409838
# 3  Financial District  37.789005 -122.402346
# 4     Pacific Heights  37.789007 -122.434913
#
#                                         related_addr        street_name  \
# 0  [['897 Hyde St, San Francisco, CA 94109, USA',...        Hyde Street
# 1  [['1455 Van Ness Ave, San Francisco, CA 94109,...    Van Ness Avenue
# 2  [['575 Sutter St, San Francisco, CA 94102, USA...       Mason Street
# 3  [['19-31 Post St, San Francisco, CA 94104, USA...        Post Street
# 4  [['2450 California St, San Francisco, CA 94115...  California Street
#
#   street_no zipcode
# 0       897   94109
# 1      1400   94109
# 2       530   94108
# 3     19-31   94104
# 4      2450   94115

# %%
parking_gps[parking_gps['orig_lng'] == -122.414177]
# Out:
# Empty DataFrame
# Columns: [Search_GPS, address_tags, neighborhood, orig_lat, orig_lng, related_addr, street_name, street_no, zipcode]
# Index: []

# %%
w2 = str(37.7716371)
w = str(37.7716370)
len(w2)
# Out:
# 10

# %%
df_parking['str_lat'] = df_parking['lat'].round(6).astype(str)
df_parking['str_lat'] = df_parking['str_lat'].map(lambda x : x+'0'*(9-len(x)) if len(x)<9 else x)
df_parking['str_lng'] = df_parking['lon'].round(6).astype(str)
df_parking['str_lng'] = df_parking['str_lng'].map(lambda x : x+'0'*(11-len(x)) if len(x)<11 else x)
df_parking['joinkey'] = df_parking['str_lat'].str[:9] + ',' + df_parking['str_lng'].str[:11] 
df_parking['joinkey'] = df_parking['joinkey'].str.strip()
df_parking.drop(columns=['str_lat','str_lng'], inplace=True)
df_parking.head()
# Out:
#          lat         lon       datetime    pid                joinkey
# 0  37.771637 -122.437112  1471967637400   8710  37.771637,-122.437112
# 1  37.777229 -122.465370  1459821377952  11364  37.777229,-122.465370
# 2  37.771172 -122.437683  1461349554900   8478  37.771172,-122.437683
# 3  37.777328 -122.465012  1462252229600  11458  37.777328,-122.465012
# 4  37.778664 -122.464111  1463364111300  12038  37.778664,-122.464111

# %%
stage1mrg = df_parking.merge(parking_gps, how='left', left_on='joinkey', right_on=['Search_GPS']).sort_values('Search_GPS')

# %%
stage1mrg['Search_GPS'].isna().sum()
# Out:
# 7195

# %% [markdown]
# ### Follow up

# %%
follow_up = stage1mrg[stage1mrg['Search_GPS'].isna()].groupby(['lat','lon','pid']).size().reset_index()

# %%
import googlemaps
with open('/Users/timlee/Dropbox/keys/google_api_key.txt','r') as f:
    gmap_api_key = f.read()

gmaps = googlemaps.Client( key = gmap_api_key)
output = []
raw_json = []

for lat, lng, pid, ct in follow_up.values:
    # print('Reverse pulling ... %s %s' %(lat,lng))
    geocode_result = gmaps.reverse_geocode((lat,lng))
    store_json = {
        'lat' : lat,
        'lng' : lng,
        'pid' : pid,
        'data': geocode_result
    }
    raw_json.append(store_json)

# %%
raw_json[0]
# Out:
# {'data': [{'address_components': [{'long_name': '968a',
#      'short_name': '968a',
#      'types': ['street_number']},
#     {'long_name': 'Geneva Avenue',
#      'short_name': 'Geneva Ave',
#      'types': ['route']},
#     {'long_name': 'Crocker-Amazon',
#      'short_name': 'Crocker-Amazon',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'San Francisco',
#      'short_name': 'SF',
#      'types': ['locality', 'political']},
#     {'long_name': 'San Francisco County',
#      'short_name': 'San Francisco County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '94112', 'short_name': '94112', 'types': ['postal_code']},
#     {'long_name': '3403',
#      'short_name': '3403',
#      'types': ['postal_code_suffix']}],
#    'formatted_address': '968a Geneva Ave, San Francisco, CA 94112, USA',
#    'geometry': {'location': {'lat': 37.7157961, 'lng': -122.4400454},
#     'location_type': 'ROOFTOP',
#     'viewport': {'northeast': {'lat': 37.71714508029149,
#       'lng': -122.4386964197085},
#      'southwest': {'lat': 37.7144471197085, 'lng': -122.4413943802915}}},
#    'place_id': 'ChIJP4Ztdpt-j4ARSypekUDUtp8',
#    'types': ['street_address']},
#   {'address_components': [{'long_name': 'Geneva Ave & Mission St',
#      'short_name': 'Geneva Ave & Mission St',
#      'types': ['bus_station',
#       'establishment',
#       'point_of_interest',
#       'transit_station']},
#     {'long_name': 'San Francisco',
#      'short_name': 'SF',
#      'types': ['locality', 'political']},
#     {'long_name': 'San Francisco County',
#      'short_name': 'San Francisco County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']},
#     {'long_name': '94112', 'short_name': '94112', 'types': ['postal_code']}],
#    'formatted_address': 'Geneva Ave & Mission St, San Francisco, CA 94112, USA',
#    'geometry': {'location': {'lat': 37.7164206, 'lng': -122.4408053},
#     'location_type': 'GEOMETRIC_CENTER',
#     'viewport': {'northeast': {'lat': 37.7177695802915,
#       'lng': -122.4394563197085},
#      'southwest': {'lat': 37.7150716197085, 'lng': -122.4421542802915}}},
#    'place_id': 'ChIJhTyjYJt-j4ARZEBFI1hKrf4',
#    'types': ['bus_station',
#     'establishment',
#     'point_of_interest',
#     'transit_station']},
#   {'address_components': [{'long_name': 'Crocker-Amazon',
#      'short_name': 'Crocker-Amazon',
#      'types': ['neighborhood', 'political']},
#     {'long_name': 'San Francisco',
#      'short_name': 'SF',
#      'types': ['locality', 'political']},
#     {'long_name': 'San Francisco County',
#      'short_name': 'San Francisco County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'Crocker-Amazon, San Francisco, CA, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 37.7163328,
#       'lng': -122.423334},
#      'southwest': {'lat': 37.708132, 'lng': -122.4542628}},
#     'location': {'lat': 37.71195230000001, 'lng': -122.4375836},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 37.7163328, 'lng': -122.423334},
#      'southwest': {'lat': 37.708132, 'lng': -122.4542628}}},
#    'place_id': 'ChIJsSz695h-j4AR3I6PC3e7bRQ',
#    'types': ['neighborhood', 'political']},
#   {'address_components': [{'long_name': 'San Francisco',
#      'short_name': 'SF',
#      'types': ['locality', 'political']},
#     {'long_name': 'San Francisco County',
#      'short_name': 'San Francisco County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'San Francisco, CA, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 37.9298239, 'lng': -122.28178},
#      'southwest': {'lat': 37.6398299, 'lng': -123.173825}},
#     'location': {'lat': 37.7749295, 'lng': -122.4194155},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 37.812, 'lng': -122.3482},
#      'southwest': {'lat': 37.70339999999999, 'lng': -122.527}}},
#    'place_id': 'ChIJIQBpAG2ahYAR_6128GcTUEo',
#    'types': ['locality', 'political']},
#   {'address_components': [{'long_name': '94112',
#      'short_name': '94112',
#      'types': ['postal_code']},
#     {'long_name': 'San Francisco',
#      'short_name': 'SF',
#      'types': ['locality', 'political']},
#     {'long_name': 'San Francisco County',
#      'short_name': 'San Francisco County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'San Francisco, CA 94112, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 37.735749, 'lng': -122.415459},
#      'southwest': {'lat': 37.70734789999999, 'lng': -122.4691299}},
#     'location': {'lat': 37.72254909999999, 'lng': -122.4410618},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 37.735749, 'lng': -122.415459},
#      'southwest': {'lat': 37.70734789999999, 'lng': -122.4691299}}},
#    'place_id': 'ChIJ_wUjuoN-j4ARLYl5YXTu7iQ',
#    'types': ['postal_code']},
#   {'address_components': [{'long_name': 'San Francisco County',
#      'short_name': 'San Francisco County',
#      'types': ['administrative_area_level_2', 'political']},
#     {'long_name': 'San Francisco',
#      'short_name': 'SF',
#      'types': ['locality', 'political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'San Francisco County, San Francisco, CA, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 37.9298239, 'lng': -122.28178},
#      'southwest': {'lat': 37.6398299, 'lng': -123.173825}},
#     'location': {'lat': 37.7749073, 'lng': -122.4193878},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 37.9298239, 'lng': -122.28178},
#      'southwest': {'lat': 37.6398299, 'lng': -123.173825}}},
#    'place_id': 'ChIJIQBpAG2ahYARUksNqd0_1h8',
#    'types': ['administrative_area_level_2', 'political']},
#   {'address_components': [{'long_name': 'San Francisco-Oakland-Fremont, CA',
#      'short_name': 'San Francisco-Oakland-Fremont, CA',
#      'types': ['political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'San Francisco-Oakland-Fremont, CA, CA, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 38.320945,
#       'lng': -121.4692749},
#      'southwest': {'lat': 37.1073458, 'lng': -123.024066}},
#     'location': {'lat': 37.8043507, 'lng': -121.8107079},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 38.320945, 'lng': -121.4692749},
#      'southwest': {'lat': 37.1073458, 'lng': -123.024066}}},
#    'place_id': 'ChIJGUN8-q6Ij4ARZ1tA_OojshE',
#    'types': ['political']},
#   {'address_components': [{'long_name': 'San Francisco Metropolitan Area',
#      'short_name': 'San Francisco Metropolitan Area',
#      'types': ['political']},
#     {'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'San Francisco Metropolitan Area, CA, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 38.320945,
#       'lng': -121.4692139},
#      'southwest': {'lat': 37.0538579, 'lng': -123.173825}},
#     'location': {'lat': 37.7749274, 'lng': -122.4194254},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 38.320945, 'lng': -121.4692139},
#      'southwest': {'lat': 37.0538579, 'lng': -123.173825}}},
#    'place_id': 'ChIJE156BviCj4ARKrqKa5lkEu4',
#    'types': ['political']},
#   {'address_components': [{'long_name': 'California',
#      'short_name': 'CA',
#      'types': ['administrative_area_level_1', 'political']},
#     {'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'California, USA',
#    'geometry': {'bounds': {'northeast': {'lat': 42.0095169,
#       'lng': -114.131211},
#      'southwest': {'lat': 32.528832, 'lng': -124.482003}},
#     'location': {'lat': 36.778261, 'lng': -119.4179324},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 42.0095169, 'lng': -114.131211},
#      'southwest': {'lat': 32.528832, 'lng': -124.482003}}},
#    'place_id': 'ChIJPV4oX_65j4ARVW8IJ6IJUYs',
#    'types': ['administrative_area_level_1', 'political']},
#   {'address_components': [{'long_name': 'United States',
#      'short_name': 'US',
#      'types': ['country', 'political']}],
#    'formatted_address': 'United States',
#    'geometry': {'bounds': {'northeast': {'lat': 71.5388001, 'lng': -66.885417},
#      'southwest': {'lat': 18.7763, 'lng': 170.5957}},
#     'location': {'lat': 37.09024, 'lng': -95.712891},
#     'location_type': 'APPROXIMATE',
#     'viewport': {'northeast': {'lat': 49.38, 'lng': -66.94},
#      'southwest': {'lat': 25.82, 'lng': -124.39}}},
#    'place_id': 'ChIJCzYy5IS16lQRQrfeQ5K5Oxw',
#    'types': ['country', 'political']}],
#  'lat': 37.7158145,
#  'lng': -122.4400187002,
#  'pid': 147.0}

# %%
follow_up = []
for i, rj in enumerate(raw_json):
    lat = rj['lat']
    lng = rj['lng']
    pid = rj['pid']
    one_addr_details = gpsaddr_extract_json(rj['data'])
    one_addr_details['orig_lat'] = float(lat)
    one_addr_details['orig_lng'] = float(lng)
    one_addr_details['pid'] = int(pid)
    one_addr_details['Search_GPS'] = str(lat)+','+str(lng)
    addr_collection.append(one_addr_details)
    follow_up.append(one_addr_details)

# %%
follow_up_df = pd.DataFrame(follow_up)
follow_up_df.shape
# Out:
# (91, 10)

# %%
follow_up_df.head()
# Out:
#                   Search_GPS  \
# 0    37.7158145,-122.4400187
# 1    37.7392535,-122.4699492
# 2    37.7527195,-122.4113014
# 3  37.7534865,-122.420683399
# 4  37.7542535,-122.477939201
#
#                                         address_tags        neighborhood  \
# 0  [[bus_station, establishment, point_of_interes...      Crocker-Amazon
# 1                                                NaN  West of Twin Peaks
# 2                                                NaN    Mission District
# 3                                                NaN    Mission District
# 4                                                NaN     Sunset District
#
#     orig_lat    orig_lng   pid  \
# 0  37.715815 -122.440019   147
# 1  37.739253 -122.469949  2385
# 2  37.752719 -122.411301  4166
# 3  37.753487 -122.420683  4318
# 4  37.754253 -122.477939  4584
#
#                                         related_addr      street_name  \
# 0  [[968a Geneva Ave, San Francisco, CA 94112, US...    Geneva Avenue
# 1  [[2600-2616 14th Ave, San Francisco, CA 94127,...      14th Avenue
# 2  [[2950 24th St, San Francisco, CA 94110, USA, ...      24th Street
# 3  [[1201-1215 Valencia St, San Francisco, CA 941...  Valencia Street
# 4  [[1322 Noriega St, San Francisco, CA 94122, US...   Noriega Street
#
#    street_no zipcode
# 0       968a   94112
# 1  2600-2616   94127
# 1238203  Leland Avenue        15   94134
# 326399   Leland Avenue        15   94134
# 1418097  Leland Avenue        15   94134
# 326398   Leland Avenue        15   94134
# 103223   Leland Avenue        15   94134
# 907360   Leland Avenue        15   94134
# 103222   Leland Avenue        15   94134
# 297037   Leland Avenue        15   94134
# 173974   Leland Avenue        15   94134
# 1631298  Leland Avenue        15   94134
# ...                ...       ...     ...
# 1756096            NaN       NaN     NaN
# 1756215            NaN       NaN     NaN
# 1756477            NaN       NaN     NaN
# 1756857            NaN       NaN     NaN
# 1757259            NaN       NaN     NaN
# 1757498            NaN       NaN     NaN
# 1758049            NaN       NaN     NaN
# 1759243            NaN       NaN     NaN
# 1759274            NaN       NaN     NaN
# 1759322            NaN       NaN     NaN
# 1759624            NaN       NaN     NaN
# 1760071            NaN       NaN     NaN
# 1760410            NaN       NaN     NaN
# 1760875            NaN       NaN     NaN
# 1760915            NaN       NaN     NaN
# 1761183            NaN       NaN     NaN
# 1761331            NaN       NaN     NaN
# 1761567            NaN       NaN     NaN
# 1761599            NaN       NaN     NaN
# 1761998            NaN       NaN     NaN
# 1762055            NaN       NaN     NaN
# 1762478            NaN       NaN     NaN
# 1762506            NaN       NaN     NaN
# 1762522            NaN       NaN     NaN
# 1762606            NaN       NaN     NaN
# 1763017            NaN       NaN     NaN
# 1763285            NaN       NaN     NaN
# 1763454            NaN       NaN     NaN
# 1763504            NaN       NaN     NaN
# 1764342            NaN       NaN     NaN
#
# [1765205 rows x 14 columns]

# %%
for row in follow_up_df.values:
    pid = row[-5]
    mask = stage1mrg['pid']==pid
    stage1mrg.loc[mask, 'Search_GPS'] = row[0]
    stage1mrg.loc[mask, 'address_tags'] = row[1]
    stage1mrg.loc[mask, 'neighborhood'] = row[2]
    stage1mrg.loc[mask, 'orig_lat'] = row[3]
    stage1mrg.loc[mask, 'orig_lng'] = row[4]
    stage1mrg.loc[mask, 'related_addr'] = row[6]
    stage1mrg.loc[mask, 'street_name'] = row[7]
    stage1mrg.loc[mask, 'street_no'] = row[8]
    stage1mrg.loc[mask, 'zipcode'] = row[9]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-203-bb8fd1661fde> in <module>()
#       3     mask = stage1mrg['pid']==pid
#       4     stage1mrg.loc[mask, 'Search_GPS'] = row[0]
# ----> 5     stage1mrg.loc[mask, 'address_tags'] = row[1]
#       6     stage1mrg.loc[mask, 'neighborhood'] = row[2]
#       7     stage1mrg.loc[mask, 'orig_lat'] = row[3]
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     192             key = com._apply_if_callable(key, self.obj)
#     193         indexer = self._get_setitem_indexer(key)
# --> 194         self._setitem_with_indexer(indexer, value)
#     195
#     196     def _has_valid_type(self, k, axis):
#
# ~/anaconda2/envs/py3/lib/python3.6/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     581                     value = np.array(value, dtype=object)
#     582                     if len(labels) != value.shape[1]:
# --> 583                         raise ValueError('Must have equal len keys and value '
#     584                                          'when setting with an ndarray')
#     585
#
# ValueError: Must have equal len keys and value when setting with an ndarray
