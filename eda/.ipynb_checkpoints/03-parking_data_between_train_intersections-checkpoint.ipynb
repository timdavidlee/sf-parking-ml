# %% [markdown]
# # Exploration of Training Intersections and parking
# Import libraries

# %%
import sys
sys.path.append('../')
from common import get_train, get_parking, feat_eng, get_test, add_street_sections
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# #### import data

# %%
test_df = get_test()
train_df = get_train()
train_df = feat_eng(train_df)
# Out:
# Time it took: 0.10228300094604492
# Time it took: 0.13970184326171875
# adding additional features to test and/or train ...
#
# loading parking data 1.7M
# loading address data 30K
# calculating closest joins
# merging
# complete
# fixing neighborhood string formatting
# merging in neighborhood information
# Time it took: 0.6355230808258057

# %% [markdown]
# #### Loading parking data

# %%
parking_df = get_parking()
#parking_df.info()
# Out:
# loading cached copy
# Time it took: 2.596850872039795

# %%
parking_df.shape
# Out:
# (1761328, 13)

# %%
def get_unique_coords(df, lat_field, lon_field):
    """
    Takes in a dataframe and extract unique fields for plotting.
    Uses dataframe group by to reduce the number of rows that need to
    be plotted, returns the lat and lon fields
    """
    unique = df.groupby([lat_field, lon_field]).size().reset_index()
    lat, lon= unique[lat_field].values, unique[lon_field].values
    return lat, lon


def plot_street(STREET, train_df, parking_df):
    """
    Overlays the different datasets on a 2D map for matplotlib
    """
    train_df['STREET'] = train_df['Street'].map(lambda x : x.upper())
    parking_df['STREET'] = parking_df['road'].map(lambda x : x.upper() if x is not None else x)

    kearny_t= train_df[train_df['STREET']==STREET]
    kearny_p = parking_df[parking_df['STREET']==STREET]
    
    latF, lonF = get_unique_coords(kearny_t, 'From_lat', 'From_long')
    latT, lonT = get_unique_coords(kearny_t, 'To_lat', 'To_long')
    latp, lonp = get_unique_coords(kearny_p, 'lat', 'lon')
    
    
    
    plt.figure(figsize=(7,7))
    plt.title('STREET : %s' % STREET)
    plt.scatter(latp, lonp, c='g', alpha = 0.5)
    plt.scatter(latF, lonF, c='b', alpha=0.5)
    plt.scatter(latT, lonT, c='black', alpha = 0.5)


def add_street_sections(train_df, test_df=None):
    
    train_streets = list(train_df['Street'].unique())
    train_streets = [s.upper() for s in train_streets]
    
    parking_df = get_parking()
    parking_street = list(parking_df['road'].unique())
    parking_street = [s.upper() for s in parking_street if s is not None]
    
    
    print('Identifying key streets...')
    # upper case streets for joining
    train_df['STREET'] = train_df['Street'].map(lambda x : x.upper())
    parking_df['STREET'] = parking_df['road'].map(lambda x : x.upper() if x is not None else x)

    print('Filtering down the parking data ...')
    # down filter to only training streets
    parking_sm_df = parking_df[parking_df['STREET'].isin(train_streets)]
    parking_sm_df.shape
    
    VERT_STREET = ['MISSION STREET', 'PINE STREET', '2ND STREET', 'BRYANT STREET', 
               'POST STREET', 'WASHINGTON STREET', 'JACKSON STREET', 'BUSH STREET', 
               'GEARY STREET', 'GROVE STREET', 'SUTTER STREET', 'COLUMBUS AVENUNE']
    
    print('measuring parking coords within FROM TO bounds ...')
    dist_parking = parking_sm_df.groupby(['lat','lon','STREET']).size().reset_index()
    dist_tr = train_df.groupby(['From_lat','From_long','To_lat','To_long','STREET']).size().reset_index()
    dist_tr['STR_SEC'] = dist_tr.index

    for latf, lonf, latt,lont, street, ct, id_ in dist_tr.values:
        min_lat = min(latf, latt)
        max_lat = max(latf, latt)
        min_lon = min(lonf, lont)
        max_lon = max(lonf, lont)

        if street in VERT_STREET:
            dist_parking.loc[(dist_parking['STREET'] == street) & (dist_parking['lon'] < max_lon) & (dist_parking['lon'] > min_lon),"STR_SEC" ] = id_ 
        else:
            dist_parking.loc[(dist_parking['STREET'] == street) & (dist_parking['lat'] < max_lat) & (dist_parking['lat'] > min_lat) ,"STR_SEC" ] = id_ 

    print('Adding street section ids to train and parking ...')
    rejoined_parking = parking_sm_df.merge(dist_parking[['lat','lon','STR_SEC']], how ='left', on=['lat','lon'])
    rejoined_parking = rejoined_parking[rejoined_parking['STR_SEC'].isna()!=True].copy()
    
    join_cols = ['From_lat','From_long','To_lat','To_long']
    train_df = train_df.merge(dist_tr[join_cols+['STR_SEC']], how ='left', on =join_cols)
    
    print('Complete')
    if test_df is not None:
        test_df = test_df.merge(dist_tr[join_cols+['STR_SEC']], how ='left', on =join_cols)
        return rejoined_parking, train_df, test_df
    else:
        return rejoined_parking, train_df

# %% [markdown]
# ### Loading Training and test Set

# %%
train_df = get_train()
test_df = get_train()

train_df = feat_eng(train_df)
test_df = feat_eng(test_df)

#parking_df, train_df, test_df = add_street_sections(train_df, test_df)
# Out:
# Time it took: 0.1411590576171875
# Time it took: 0.147507905960083
# adding additional features to test and/or train ...
#
# loading parking data 1.7M
# loading address data 30K
# calculating closest joins
# merging
# complete
# fixing neighborhood string formatting
# merging in neighborhood information
# Time it took: 0.5991771221160889
# adding additional features to test and/or train ...
#
# loading parking data 1.7M
# loading address data 30K
# calculating closest joins
# merging
# complete
# fixing neighborhood string formatting
# merging in neighborhood information
# Time it took: 0.6138341426849365

# %% [markdown]
# ## Plot parking  and Training data by street name only

# %%
plot_street('POLK STREET', train_df, parking_df)

# %% [markdown]
# #### Get Unique Streets

# %%
train_streets = list(train_df['Street'].unique())
train_streets = [s.upper() for s in train_streets]

parking_street = list(parking_df['road'].unique())
parking_street = [s.upper() for s in parking_street if s is not None]

# %%
train_streets
# Out:
# ['MISSION STREET',
#  'POLK STREET',
#  'VAN NESS AVENUE',
#  'LARKIN STREET',
#  'PINE STREET',
#  '23RD STREET',
#  'BRYANT STREET',
#  'JESSIE STREET',
#  'KEARNY STREET',
#  'POST STREET',
#  'WASHINGTON STREET',
#  'JACKSON STREET',
#  'BUSH STREET',
#  'LEAVENWORTH STREET',
#  'JONES STREET',
#  'GEARY STREET',
#  'TAYLOR STREET',
#  'GROVE STREET',
#  'SUTTER STREET',
#  'HYDE STREET',
#  'MASON STREET',
#  'MONTGOMERY STREET',
#  'BATTERY STREET',
#  'STOCKTON STREET',
#  'COLUMBUS AVENUE',
#  'REDWOOD STREET']

# %% [markdown]
# ### change streets to uppercase

# %%
train_df['STREET'] = train_df['Street'].map(lambda x : x.upper())
parking_df['STREET'] = parking_df['road'].map(lambda x : x.upper() if x is not None else x)

# %%
parking_sm_df = parking_df[parking_df['STREET'].isin(train_streets)]
parking_sm_df.shape
# Out:
# (347910, 14)

# %% [markdown]
# ### Get unique coordinates

# %%
def plot_unique_coords(df, lat_field, lon_field):
    unique = df.groupby([lat_field, lon_field]).size().reset_index()
    lat, lon= unique[lat_field].values, unique[lon_field].values
    return lat, lon

# %%
lat_tr, lon_tr = train_df['From_lat'].values, train_df['From_long'].values

# %%
lat, lon = plot_unique_coords(parking_sm_df, 'lat', 'lon')
latp, lonp = plot_unique_coords(parking_df, 'lat', 'lon')

# %%
plt.figure(figsize=(11,11))
#plt.scatter(latp, lonp, c='g', alpha = 0.5)
plt.scatter(lat, lon, c='b', alpha=0.1)
plt.scatter(lat_tr, lon_tr, c='r', alpha = 0.1)

# %% [markdown]
# ### Plotting function for coordinates

# %%
def plot_street(STREET):
    train_streets = list(train_df['Street'].unique())
    train_streets = [s.upper() for s in train_streets]
    
    parking_street = list(parking_df['road'].unique())
    parking_street = [s.upper() for s in parking_street if s is not None]

    kearny_t= train_df[train_df['STREET']==STREET]
    kearny_p = parking_sm_df[parking_sm_df['STREET']==STREET]
    
    latF, lonF = plot_unique_coords(kearny_t, 'From_lat', 'From_long')
    latT, lonT = plot_unique_coords(kearny_t, 'To_lat', 'To_long')
    latp, lonp = plot_unique_coords(kearny_p, 'lat', 'lon')
    
    
    plt.figure(figsize=(7,7))
    plt.title('STREET : %s' % STREET)
    plt.scatter(latp, lonp, c='g', alpha = 0.5)
    plt.scatter(latF, lonF, c='b', alpha=0.5)
    plt.scatter(latT, lonT, c='black', alpha = 0.5)

# %%
for street in train_streets:
    plot_street(street)
# Out:
# /Users/timlee/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# ### Sample Overlay of Street

# %%
STREET = 'LARKIN STREET'

# %%
kearny_t= train_df[train_df['STREET']==STREET]

# %%
kearny_p = parking_sm_df[parking_sm_df['STREET']==STREET]

# %%
latF, lonF = plot_unique_coords(kearny_t, 'From_lat', 'From_long')
latT, lonT = plot_unique_coords(kearny_t, 'To_lat', 'To_long')
latp, lonp = plot_unique_coords(kearny_p, 'lat', 'lon')

# %%
plt.figure(figsize=(11,11))
plt.scatter(latp, lonp, c='g', alpha = 0.5)
plt.scatter(latF, lonF, c='b', alpha=0.5)
plt.scatter(latT, lonT, c='black', alpha = 0.5)

# %% [markdown]
# ### Bounding box routing (how we filter out other points that over shoot the street

# %%
VERT_STREET = ['MISSION STREET', 'PINE STREET', '2ND STREET', 'BRYANT STREET', 
               'POST STREET', 'WASHINGTON STREET', 'JACKSON STREET', 'BUSH STREET', 
               'GEARY STREET', 'GROVE STREET', 'SUTTER STREET', 'COLUMBUS AVENUNE']

# %%
dist_parking = parking_sm_df.groupby(['lat','lon','STREET']).size().reset_index()
dist_tr = train_df.groupby(['From_lat','From_long','To_lat','To_long','STREET']).size().reset_index()
dist_tr['STR_SEC'] = dist_tr.index

for latf, lonf, latt,lont, street, ct, id_ in dist_tr.values:
    min_lat = min(latf, latt)
    max_lat = max(latf, latt)
    min_lon = min(lonf, lont)
    max_lon = max(lonf, lont)
    
    if street in VERT_STREET:
        dist_parking.loc[(dist_parking['STREET'] == street) & (dist_parking['lon'] < max_lon) & (dist_parking['lon'] > min_lon),"STR_SEC" ] = id_ 
    else:
        dist_parking.loc[(dist_parking['STREET'] == street) & (dist_parking['lat'] < max_lat) & (dist_parking['lat'] > min_lat) ,"STR_SEC" ] = id_

# %% [markdown]
# ### Once all the points have tagged, we only filter for parking between street segments

# %%
rejoined_parking = parking_sm_df.merge(dist_parking[['lat','lon','STR_SEC']], how ='left', on=['lat','lon'])
rejoined_parking = rejoined_parking[rejoined_parking['STR_SEC'].isna()!=True].copy()

# %%
rejoined_parking.shape
# Out:
# (124185, 15)

# %% [markdown]
# ### Plot the remaining points

# %%
latF, lonF = plot_unique_coords(train_df, 'From_lat', 'From_long')
latT, lonT = plot_unique_coords(train_df, 'To_lat', 'To_long')
latp, lonp = plot_unique_coords(rejoined_parking, 'lat', 'lon')

plt.figure(figsize=(11,11))
plt.scatter(latp, lonp, c='g', alpha = 0.5)
plt.scatter(latF, lonF, c='b', alpha=0.5)
plt.scatter(latT, lonT, c='black', alpha = 0.5)

# %% [markdown]
# ### Add join columns to training data

# %%
join_cols = ['From_lat','From_long','To_lat','To_long']
train_df = train_df.merge(dist_tr[join_cols+['STR_SEC']], how ='left', on =join_cols)

# %% [markdown]
# # Double checking by different streets

# %%
parking_df, train_df, test_df = add_street_sections(train_df, test_df)
# Out:
# loading cached copy
# Time it took: 2.8279221057891846
# Identifying key streets...
# Filtering down the parking data ...
# measuring parking coords within FROM TO bounds ...
# Adding street section ids to train and parking ...
# Complete

# %% [markdown]
# ### Check out section 6
# ### Check out section 26

# %%
section_number = 26
print(train_df.loc[train_df['STR_SEC']==section_number, ['Street', 'From', 'To']])
latF, lonF = plot_unique_coords(train_df[train_df['STR_SEC']==section_number], 'From_lat', 'From_long')
latT, lonT = plot_unique_coords(train_df[train_df['STR_SEC']==section_number], 'To_lat', 'To_long')
latp, lonp = plot_unique_coords(parking_df[parking_df['STR_SEC']==section_number], 'lat', 'lon')

plt.figure(figsize=(11,11))
plt.scatter(latp, lonp, c='g', alpha = 0.5)
plt.scatter(latF, lonF, c='b', alpha=0.5)
plt.scatter(latT, lonT, c='black', alpha = 0.5)
# Out:
#                   Street         From           To
# 255   Leavenworth Street  Turk Street  Eddy Street
# 256   Leavenworth Street  Turk Street  Eddy Street
# 699   Leavenworth Street  Turk Street  Eddy Street
# 700   Leavenworth Street  Turk Street  Eddy Street
# 827   Leavenworth Street  Turk Street  Eddy Street
# 910   Leavenworth Street  Turk Street  Eddy Street
# 1043  Leavenworth Street  Turk Street  Eddy Street
# 1135  Leavenworth Street  Turk Street  Eddy Street
# 1136  Leavenworth Street  Turk Street  Eddy Street

# %%
train_df[train_df['Street'] == 'Jones Street' ]
# Out:
#             Street            From             To       Date   Time  \
# 214   Jones Street    Ellis Street    Eddy Street 2014-02-03  13:56
# 272   Jones Street     Bush Street  Sutter Street 2014-02-03  13:44
# 273   Jones Street   Sutter Street   Jones Street 2014-02-03  13:44
# 274   Jones Street     Post Street    Colin Place 2014-02-03  13:44
# 275   Jones Street     Colin Place   Geary Street 2014-02-03  13:44
# 276   Jones Street  Antonio Street   Ellis Street 2014-02-03  13:56
# 465   Jones Street    Ellis Street    Eddy Street 2014-02-16  12:50
# 518   Jones Street    Ellis Street    Eddy Street 2014-02-25  11:18
# 529   Jones Street     Bush Street  Sutter Street 2014-02-25  11:17
# 530   Jones Street   Sutter Street   Jones Street 2014-02-25  11:17
# 531   Jones Street     Post Street    Colin Place 2014-02-25  11:17
# 532   Jones Street     Colin Place   Geary Street 2014-02-25  11:17
# 533   Jones Street  Antonio Street   Ellis Street 2014-02-25  11:18
# 639   Jones Street    Ellis Street    Eddy Street 2014-03-15  18:30
# 640   Jones Street    Ellis Street    Eddy Street 2014-03-15  19:41
# 641   Jones Street    Ellis Street    Eddy Street 2014-03-15  20:41
# 745   Jones Street     Bush Street  Sutter Street 2014-03-15  18:29
# 746   Jones Street     Bush Street  Sutter Street 2014-03-15  20:39
# 747   Jones Street   Sutter Street   Jones Street 2014-03-15  10:21
# 748   Jones Street   Sutter Street   Jones Street 2014-03-15  18:29
# 749   Jones Street   Sutter Street   Jones Street 2014-03-15  20:39
# 750   Jones Street     Post Street    Colin Place 2014-03-15  18:29
# 751   Jones Street     Post Street    Colin Place 2014-03-15  20:39
# 752   Jones Street     Colin Place   Geary Street 2014-03-15  18:29
# 753   Jones Street     Colin Place   Geary Street 2014-03-15  20:39
# 754   Jones Street  Antonio Street   Ellis Street 2014-03-15  18:30
# 755   Jones Street  Antonio Street   Ellis Street 2014-03-15  20:41
# 767   Jones Street    Ellis Street    Eddy Street 2014-03-21  20:39
# 846   Jones Street     Bush Street  Sutter Street 2014-03-21  20:37
# 847   Jones Street   Sutter Street   Jones Street 2014-03-21  20:37
# 848   Jones Street     Post Street    Colin Place 2014-03-21  20:37
# 849   Jones Street     Colin Place   Geary Street 2014-03-21  20:37
# 850   Jones Street  Antonio Street   Ellis Street 2014-03-21  20:39
# 854   Jones Street    Ellis Street    Eddy Street 2014-03-22  14:27
# 929   Jones Street     Bush Street  Sutter Street 2014-03-22  14:25
# 930   Jones Street   Sutter Street   Jones Street 2014-03-22  14:25
# 931   Jones Street     Post Street    Colin Place 2014-03-22  14:25
# 932   Jones Street     Colin Place   Geary Street 2014-03-22  14:25
# 933   Jones Street  Antonio Street   Ellis Street 2014-03-22  14:27
# 1019  Jones Street     Bush Street  Sutter Street 2014-03-26  17:02
# 1023  Jones Street    Ellis Street    Eddy Street 2014-03-27  14:33
# 1076  Jones Street   Sutter Street   Jones Street 2014-03-27  14:05
# 1086  Jones Street    Ellis Street    Eddy Street 2014-03-28  19:19
# 1087  Jones Street    Ellis Street    Eddy Street 2014-03-28  22:03
#
#       Real.Spots  Street.Length  any_spot  holiday  day   ...     f_pop  \
# 214            8     104.767970         1        0    3   ...      41.5
# 272            2     105.073950         1        0    3   ...      31.8
# 273            2      72.917170         1        0    3   ...      48.0
# 274            0      32.078580         0        0    3   ...      41.5
# 275            5      72.545090         1        0    3   ...      41.5
# 276            7      51.088688         1        0    3   ...      41.5
# 465            0     104.767970         0        0   16   ...      41.5
# 518            0     104.767970         0        0   25   ...      41.5
# 529            0     105.073950         0        0   25   ...      31.8
# 530            0      72.917170         0        0   25   ...      48.0
# 531            0      32.078580         0        0   25   ...      41.5
# 532            0      72.545090         0        0   25   ...      41.5
# 533            1      51.088688         1        0   25   ...      41.5
# 639            0     104.767970         0        0   15   ...      41.5
# 640            0     104.767970         0        0   15   ...      41.5
# 641            0     104.767970         0        0   15   ...      41.5
# 745            0     105.073950         0        0   15   ...      31.8
# 746            0     105.073950         0        0   15   ...      31.8
# 747            0      72.917170         0        0   15   ...      48.0
# 748            0      72.917170         0        0   15   ...      48.0
# 749            1      72.917170         1        0   15   ...      48.0
# 750            0      32.078580         0        0   15   ...      41.5
# 751            0      32.078580         0        0   15   ...      41.5
# 752            0      72.545090         0        0   15   ...      41.5
# 753            0      72.545090         0        0   15   ...      41.5
# 754            1      51.088688         1        0   15   ...      41.5
# 755            0      51.088688         0        0   15   ...      41.5
# 767            0     104.767970         0        0   21   ...      41.5
# 846            0     105.073950         0        0   21   ...      31.8
# 847            0      72.917170         0        0   21   ...      48.0
# 848            0      32.078580         0        0   21   ...      41.5
# 849            0      72.545090         0        0   21   ...      41.5
# 850            0      51.088688         0        0   21   ...      41.5
# 854            0     104.767970         0        0   22   ...      41.5
# 929            0     105.073950         0        0   22   ...      31.8
# 930            3      72.917170         1        0   22   ...      48.0
# 931            0      32.078580         0        0   22   ...      41.5
# 932            1      72.545090         1        0   22   ...      41.5
# 933            5      51.088688         1        0   22   ...      41.5
# 1019           0     105.073950         0        0   26   ...      31.8
# 1023           3     104.767970         1        0   27   ...      41.5
# 1076           0      72.917170         0        0   27   ...      48.0
# 1086           0     104.767970         0        0   28   ...      41.5
# 1087           1     104.767970         1        0   28   ...      41.5
#
#       house_avg_value  house_pct  m_pop  med_age     pop  twn_avg_value  \
# 214               NaN        NaN   41.2     41.5  9194.0            NaN
# 272               NaN        NaN   39.2     31.8    47.0            NaN
# 273               NaN        NaN   45.3     48.0  9085.0            NaN
# 274               NaN        NaN   41.2     41.5  9194.0            NaN
# 275               NaN        NaN   41.2     41.5  9194.0            NaN
# 276               NaN        NaN   41.2     41.5  9194.0            NaN
# 465               NaN        NaN   41.2     41.5  9194.0            NaN
# 518               NaN        NaN   41.2     41.5  9194.0            NaN
# 529               NaN        NaN   39.2     31.8    47.0            NaN
# 530               NaN        NaN   45.3     48.0  9085.0            NaN
# 531               NaN        NaN   41.2     41.5  9194.0            NaN
# 532               NaN        NaN   41.2     41.5  9194.0            NaN
# 533               NaN        NaN   41.2     41.5  9194.0            NaN
# 639               NaN        NaN   41.2     41.5  9194.0            NaN
# 640               NaN        NaN   41.2     41.5  9194.0            NaN
# 641               NaN        NaN   41.2     41.5  9194.0            NaN
# 745               NaN        NaN   39.2     31.8    47.0            NaN
# 746               NaN        NaN   39.2     31.8    47.0            NaN
# 747               NaN        NaN   45.3     48.0  9085.0            NaN
# 748               NaN        NaN   45.3     48.0  9085.0            NaN
# 749               NaN        NaN   45.3     48.0  9085.0            NaN
# 750               NaN        NaN   41.2     41.5  9194.0            NaN
# 751               NaN        NaN   41.2     41.5  9194.0            NaN
# 752               NaN        NaN   41.2     41.5  9194.0            NaN
# 753               NaN        NaN   41.2     41.5  9194.0            NaN
# 754               NaN        NaN   41.2     41.5  9194.0            NaN
# 755               NaN        NaN   41.2     41.5  9194.0            NaN
# 767               NaN        NaN   41.2     41.5  9194.0            NaN
# 846               NaN        NaN   39.2     31.8    47.0            NaN
# 847               NaN        NaN   45.3     48.0  9085.0            NaN
# 848               NaN        NaN   41.2     41.5  9194.0            NaN
# 849               NaN        NaN   41.2     41.5  9194.0            NaN
# 850               NaN        NaN   41.2     41.5  9194.0            NaN
# 854               NaN        NaN   41.2     41.5  9194.0            NaN
# 929               NaN        NaN   39.2     31.8    47.0            NaN
# 930               NaN        NaN   45.3     48.0  9085.0            NaN
# 931               NaN        NaN   41.2     41.5  9194.0            NaN
# 932               NaN        NaN   41.2     41.5  9194.0            NaN
# 933               NaN        NaN   41.2     41.5  9194.0            NaN
# 1019              NaN        NaN   39.2     31.8    47.0            NaN
# 1023              NaN        NaN   41.2     41.5  9194.0            NaN
# 1076              NaN        NaN   45.3     48.0  9085.0            NaN
# 1086              NaN        NaN   41.2     41.5  9194.0            NaN
# 1087              NaN        NaN   41.2     41.5  9194.0            NaN
#
#       twn_pct        STREET  STR_SEC
# 214       NaN  JONES STREET       32
# 272       NaN  JONES STREET       61
# 273       NaN  JONES STREET       54
# 274       NaN  JONES STREET       48
# 275       NaN  JONES STREET       47
# 276       NaN  JONES STREET       34
# 465       NaN  JONES STREET       32
# 518       NaN  JONES STREET       32
# 529       NaN  JONES STREET       61
# 530       NaN  JONES STREET       54
# 531       NaN  JONES STREET       48
# 532       NaN  JONES STREET       47
# 533       NaN  JONES STREET       34
# 639       NaN  JONES STREET       32
# 640       NaN  JONES STREET       32
# 641       NaN  JONES STREET       32
# 745       NaN  JONES STREET       61
# 746       NaN  JONES STREET       61
# 747       NaN  JONES STREET       54
# 748       NaN  JONES STREET       54
# 749       NaN  JONES STREET       54
# 750       NaN  JONES STREET       48
# 751       NaN  JONES STREET       48
# 752       NaN  JONES STREET       47
# 753       NaN  JONES STREET       47
# 754       NaN  JONES STREET       34
# 755       NaN  JONES STREET       34
# 767       NaN  JONES STREET       32
# 846       NaN  JONES STREET       61
# 847       NaN  JONES STREET       54
# 848       NaN  JONES STREET       48
# 849       NaN  JONES STREET       47
# 850       NaN  JONES STREET       34
# 854       NaN  JONES STREET       32
# 929       NaN  JONES STREET       61
# 930       NaN  JONES STREET       54
# 931       NaN  JONES STREET       48
# 932       NaN  JONES STREET       47
# 933       NaN  JONES STREET       34
# 1019      NaN  JONES STREET       61
# 1023      NaN  JONES STREET       32
# 1076      NaN  JONES STREET       54
# 1086      NaN  JONES STREET       32
# 1087      NaN  JONES STREET       32
#
# [44 rows x 51 columns]
