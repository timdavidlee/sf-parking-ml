# %% [markdown]
# ### Pulling Neighborhood stats on Population and SQ area
# http://www.city-data.com/nbmaps/neigh-San-Francisco-California.html

# %%
from scrapy.selector import Selector
import newspaper

# %%
b = "a"
b.isupper
# Out:
# <function str.isupper>

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# #### Pull data from city-data

# %%
resp = requests.get('http://www.city-data.com/nbmaps/neigh-San-Francisco-California.html')

# %% [markdown]
# #### Beautiful Soup teh data

# %%
soup = BeautifulSoup(resp.content,'html.parser')

# %%
neighboorhoods = Selector(text=resp.content).xpath("//div[@class='neighborhood']").extract()

# %% [markdown]
# #### String Clean up

# %%
replace = {"Alamo Square":"alamosquare"
,"Anza Vista":"anzavista"
,"Aquatic Park":"aquaticpark"
,"Baja Noe":"bajanoe"
,"Balboa Park":"balboapark"
,"Balboa Terrace":"balboaterrace"
,"Bayview District":"bayviewdistrict"
,"Bayview Heights":"bayviewheights"
,"Bernal Heights":"bernalheights"
,"Bernal Heights North":"bernalheightsnorth"
,"Bernal Heights Park":"bernalheightspark"
,"Bernal Heights South":"bernalheightssouth"
,"Buena Vista Park":"buenavistapark"
,"Castro":"castro"
,"Cathedral Hill":"cathedralhill"
,"Cayuga Terrace":"cayugaterrace"
,"Central Richmond":"centralrichmond"
,"Central Sunset":"centralsunset"
,"Chinatown":"chinatown"
,"Civic Center":"civiccenter"
,"Clarendon Heights":"clarendonheights"
,"Cole Valley":"colevalley"
,"Corona Heights":"coronaheights"
,"Cow Hollow":"cowhollow"
,"Crocker-Amazon":"crocker-amazon"
,"Deco Ghetto":"decoghetto"
,"Diamond Heights":"diamondheights"
,"Dogpatch":"dogpatch"
,"Downtown":"downtown"
,"Duboce Triangle":"dubocetriangle"
,"Embarcadero":"embarcadero"
,"Excelsior":"excelsior"
,"Financial District":"financialdistrict"
,"Financial District South":"financialdistrictsouth"
,"Fisherman's Wharf":"fisherman'swharf"
,"Forest Hill":"foresthill"
,"Forest Knolls":"forestknolls"
,"Fort Mason":"fortmason"
,"French Quarter":"frenchquarter"
,"Ghirardelli Square":"ghirardellisquare"
,"Glen Park":"glenpark"
,"Golden Gate Heights":"goldengateheights"
,"Golden Gate Park":"goldengatepark"
,"Haight-Ashbury":"haight-ashbury"
,"Hayes Valley":"hayesvalley"
,"Holly Park":"hollypark"
,"Hunters Point":"hunterspoint"
,"India Basin":"indiabasin"
,"Ingleside":"ingleside"
,"Ingleside Heights":"inglesideheights"
,"Ingleside Terrace":"inglesideterrace"
,"Inner Parkside":"innerparkside"
,"Inner Richmond":"innerrichmond"
,"Inner Sunset":"innersunset"
,"Inner Sunset":"innersunset"
,"Inset":"inset"
,"Intermission":"intermission"
,"Jackson Square":"jacksonsquare"
,"Japantown":"japantown"
,"Laguna Honda":"lagunahonda"
,"Lake":"lake"
,"Lake Shore":"lakeshore"
,"Lakeside":"lakeside"
,"Laurel Heights":"laurelheights"
,"Laurel Village":"laurelvillage"
,"Little Hollywood":"littlehollywood"
,"Little Russia":"littlerussia"
,"Little Saigon":"littlesaigon"
,"Lone Mountain":"lonemountain"
,"Lower Haight":"lowerhaight"
,"Lower Nob Hill":"lowernobhill"
,"Lower Pacific Heights":"lowerpacificheights"
,"Marina District":"marinadistrict"
,"Mastro":"mastro"
,"Merced Heights":"mercedheights"
,"Merced Manor":"mercedmanor"
,"Midtown Terrace":"midtownterrace"
,"Mint Hill":"minthill"
,"Miraloma Park":"miralomapark"
,"Mission Bay":"missionbay"
,"Mission District":"missiondistrict"
,"Mission Dolores":"missiondolores"
,"Mission Terrace":"missionterrace"
,"Monterey Heights":"montereyheights"
,"Mount Davidson Manor":"mountdavidsonmanor"
,"NOMA":"noma"
,"Nob Hill":"nobhill"
,"Noe Valley":"noevalley"
,"North Beach":"northbeach"
,"North Panhandle":"northpanhandle"
,"North Waterfront":"northwaterfront"
,"Oceanview":"oceanview"
,"Outer Mission":"outermission"
,"Outer Parkside":"outerparkside"
,"Outer Richmond":"outerrichmond"
,"Outer Sunset":"outersunset"
,"Outset":"outset"
,"Pacific Heights":"pacificheights"
,"Park Merced":"parkmerced"
,"Parkside":"parkside"
,"Parnassus":"parnassus"
,"Pier 39":"pier39"
,"Pine Lake Park":"pinelakepark"
,"Polk Gulch":"polkgulch"
,"Portola":"portola"
,"Potrero Flats":"potreroflats"
,"Potrero Hill":"potrerohill"
,"Presidio":"presidio"
,"Presidio Heights":"presidioheights"
,"Presidio Terrace":"presidioterrace"
,"Richmond District":"richmonddistrict"
,"Rincon Hill":"rinconhill"
,"Russian Hill":"russianhill"
,"SOMISSPO":"somisspo"
,"Saint Francis Wood":"saintfranciswood"
,"Sea Cliff":"seacliff"
,"Sherwood Forest":"sherwoodforest"
,"Showplace Square":"showplacesquare"
,"Silver Terrace":"silverterrace"
,"South Basin":"southbasin"
,"South Beach":"southbeach"
,"South Of Market":"southofmarket"
,"South Park":"southpark"
,"St Marys Square":"stmaryssquare"
,"Stonestown":"stonestown"
,"Sunnydale":"sunnydale"
,"Sunnyside":"sunnyside"
,"Sunset District":"sunsetdistrict"
,"Sutro Heights":"sutroheights"
,"Telegraph Hill":"telegraphhill"
,"Tenderloin":"tenderloin"
,"The Hub":"thehub"
,"Transmission":"transmission"
,"Treasure Island":"treasureisland"
,"Twin Peaks":"twinpeaks"
,"Twin Peaks West":"twinpeakswest"
,"Union Square":"unionsquare"
,"Upper Market":"uppermarket"
,"Van Ness":"vanness"
,"Visitacion Valley":"visitacionvalley"
,"West Portal":"westportal"
,"West of Twin Peaks":"westoftwinpeaks"
,"Western Addition":"westernaddition"
,"Westwood Highlands":"westwoodhighlands"
,"Westwood Park":"westwoodpark"
,"Yerba Buena Island":"yerbabuenaisland"
,"Zion District":"ziondistrict"
,"Mission Deluxe" :"missiondeluxe"
,"bernalheights North": "bernalheights_n"
,"bernalheights Park": "bernalheights_p"
,"bernalheights South": "bernalheights_s"
,"Eureka Valley": "eurekavalley"
,"FiDi": "fidi"
}

# %% [markdown]
# #### Get Only text from the HTML (no tags)

# %%
text_only = []
for neigh in neighboorhoods:
    soup = BeautifulSoup(neigh,'html.parser')
    text_only.append(soup.get_text())

# %%
text_only[0]
# Out:
# "Alamo Square neighborhood in San Francisco statistics: (Find on map)\nArea: 0.144 square milesPopulation: 5,903Population density:Alamo Square:41,104 people per square mileSan Francisco:18,651 people per square mileMedian household income in 2016: Alamo Square:$119,678San Francisco:$103,801Median rent in in 2016: Alamo Square:$1,769San Francisco:$1,731Male vs FemalesMales:3,431Females:2,471Median ageMales:35.7 yearsFemales:38.8 yearsHousing prices:Average estimated value of detached houses in 2016 (4.5% of all units):Alamo Square:$2,122,937San Francisco:$1,418,931Average estimated value of townhouses or other attached units in 2016 (2.6% of all units):This neighborhood:$1,041,250city:$1,130,973Average estimated value of housing units in 2-unit structures in 2016 (12.3% of all units):This neighborhood:$1,215,016San Francisco:$1,365,931Average estimated '16 value of housing units in 3-to-4-unit structures (26.1% of all units):Alamo Square:$916,341city:$1,328,617Average estimated '16 v
# ...

# %% [markdown]
# #### Look for these specific metrics to text parse

# %%
metrics = ['Area','Population density','Median age', 'Housing prices', 'Population','Median household income', 'Median rent','Males:', 'Females:','Average estimated', 'Most popular']

# %%
clean_text_only = []

for tx in text_only:
    for m in metrics:
        tx = tx.replace(m,'\n-'+m)
    for k,v in replace.items():
        tx = tx.replace(k,v)
    clean_text_only.append(tx)

# %%
print(clean_text_only[0])
# Out:
# alamosquare neighborhood in San Francisco statistics: (Find on map)
#
# -Area: 0.144 square miles
# -Population: 5,903
# -
# -Population density:alamosquare:41,104 people per square mileSan Francisco:18,651 people per square mile
# -Median household income in 2016: alamosquare:$119,678San Francisco:$103,801
# -Median rent in in 2016: alamosquare:$1,769San Francisco:$1,731Male vs Females
# -Males:3,431
# -Females:2,471
# -Median age
# -Males:35.7 years
# -Females:38.8 years
# -Housing prices:
# -Average estimated value of detached houses in 2016 (4.5% of all units):alamosquare:$2,122,937San Francisco:$1,418,931
# -Average estimated value of townhouses or other attached units in 2016 (2.6% of all units):This neighborhood:$1,041,250city:$1,130,973
# -Average estimated value of housing units in 2-unit structures in 2016 (12.3% of all units):This neighborhood:$1,215,016San Francisco:$1,365,931
# ...

# %% [markdown]
# #### Pull stats from data

# %%
city_stats = []
for i, section in enumerate(clean_text_only):
    output = {}
    lines = section.split('\n')
    output['neighborhood'] = lines[0].split(' ')[0]
    output['_id'] = i
    for line in lines:        
        if 'Area:' in line:
            output['area'] = line.split(':')[1].strip() 
        if 'Population:' in line:
            output['pop'] = line.split(':')[1].strip()
        if 'people per square miles' in line:
            output['ppl_density'] = line.split(':')[2].split(' ')[0]
            if output['ppl_density'] == '18,651':
                output['ppl_density'] = line.split(':')[1].split(' ')[0]
        if ('Males:' in line) and ('years' in line):
            output['med_age'] = line.split(':')[1].strip()
        if ('Females:' in line) and ('years' in line):
            output['med_age'] = line.split(':')[1].strip()            
        if ('Males:' in line):
            output['m_pop'] = line.split(':')[1].strip()
        if 'Females:' in line:
            output['f_pop'] = line.split(':')[1].strip()
        if 'Average estimated value of detached houses in 2016' in line:
            output['house_pct'] = line.split('(')[1].split('%')[0]
            output['house_avg_value'] = line.split(':')[2].split('San')[0]
        if 'Average estimated value of townhouses' in line:
            output['twn_pct'] = line.split('(')[1].split('%')[0]
            output['twn_avg_value'] = line.split(':')[2].split('San')[0]
        if 'Average estimated value of housing units in 2-unit structures' in line:
            output['apt2_pct'] = line.split('(')[1].split('%')[0]
            output['apt2_avg_value'] = line.split(':')[2].split('San')[0]
        if "Average estimated '16 value of housing units in 3-to-4-unit structures" in line:
            output['apt4_pct'] = line.split('(')[1].split('%')[0]
            output['apt4_avg_value'] = line.split(':')[2].split('San')[0]
               
    city_stats.append(output)

# %%
print(clean_text_only[4])
# Out:
# balboapark neighborhood in San Francisco statistics: (Find on map)
#
# -Area: 0.048 square miles
# -Population: 718
# -
# -Population density:balboapark:14,932 people per square mileSan Francisco:18,651 people per square mile
# -Median household income in 2016: balboapark:$80,849San Francisco:$103,801
# -Median rent in in 2016: balboapark:$1,446San Francisco:$1,731Male vs Females
# -Males:402
# -Females:316
# -Median age
# -Males:38.2 years
# -Females:46.0 years
# -Most popular occupations of males: management occupations (except farmers) (14.7%); sales and office occupations (14.6%); transportation occupations (11.8%); material moving occupations (10.0%); construction, extraction, and maintenance occupations (9.2%); business and financial operations occupations (5.6%); computer and mathematical occupations (4.2%)
# ...

# %% [markdown]
# ### Save to a DataFrame

# %%
import pandas as pd
import numpy as np

def clean_dollars(x):
    if type(x) != float:
        return x.replace('$','').replace(',','').replace('city','')

def clean_age(x):
    if type(x) != float:
        return x.replace('years','')

cs = pd.DataFrame(city_stats)
cs['twn_avg_value'] = cs['twn_avg_value'].map(clean_dollars)
cs['apt2_avg_value'] = cs['apt2_avg_value'].map(clean_dollars)
cs['apt4_avg_value'] = cs['apt4_avg_value'].map(clean_dollars)
cs['area'] = cs['area'].str.replace('square miles','')
cs['area'] = cs['area'].map(lambda x : x.split(' ')[0])
cs['house_avg_value'] = cs['house_avg_value'].map(clean_dollars)
cs['f_pop'] = cs['f_pop'].map(clean_age)
cs['m_pop'] = cs['m_pop'].map(clean_age)
cs['med_age'] = cs['med_age'].map(clean_age)
cs['pop'] = cs['pop'].map(clean_dollars)
num_cols = [col for col in cs.columns if col != 'neighborhood'] 
for col in num_cols:
    print(col)
    cs[col] = cs[col].astype(float)
cs.head()
# Out:
# _id
# apt2_avg_value
# apt2_pct
# apt4_avg_value
# apt4_pct
# area
# f_pop
# house_avg_value
# house_pct
# m_pop
# med_age
# pop
# twn_avg_value
# twn_pct
#    _id  apt2_avg_value  apt2_pct  apt4_avg_value  apt4_pct   area  f_pop  \
# 0  0.0       1215016.0      12.3        916341.0      26.1  0.144   38.8
# 1  1.0        581625.0      19.1        205001.0      21.9  0.124   37.2
# 2  2.0        160352.0       4.1        513848.0      33.3  0.037   48.2
# 3  3.0       6123081.0      15.1       1033189.0      22.2  0.055   37.3
# 4  4.0             NaN       NaN             NaN       NaN  0.048   46.0
#
#    house_avg_value  house_pct  m_pop  med_age neighborhood     pop  \
# 0        2122937.0        4.5   35.7     38.8  alamosquare  5903.0
# 1         815179.0        6.8   39.5     37.2    anzavista  2073.0
# 2        1780721.0       10.8   44.1     48.2  aquaticpark   293.0
# 3        1421754.0       10.6   36.8     37.3      bajanoe  2228.0
# ...

# %%
cs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Data columns (total 15 columns):
# _id                147 non-null float64
# apt2_avg_value     84 non-null float64
# apt2_pct           84 non-null float64
# apt4_avg_value     72 non-null float64
# apt4_pct           72 non-null float64
# area               147 non-null float64
# f_pop              144 non-null float64
# house_avg_value    119 non-null float64
# house_pct          119 non-null float64
# m_pop              144 non-null float64
# med_age            144 non-null float64
# neighborhood       147 non-null object
# pop                144 non-null float64
# twn_avg_value      114 non-null float64
# twn_pct            114 non-null float64
# dtypes: float64(14), object(1)
# memory usage: 17.3+ KB

# %%
cs.to_csv('../ref_data/nh_city_stats.txt', sep='|')

# %% [markdown]
# #### Sample of the Data

# %%
# Out:
#      _id apt2_avg_value apt2_pct  apt4_avg_value apt4_pct  \
# 0      0     $1,215,016     12.3    $916,341city     26.1
# 1      1       $581,625     19.1    $205,001city     21.9
# 2      2       $160,352      4.1    $513,848city     33.3
# 3      3     $6,123,081     15.1  $1,033,189city     22.2
# 4      4            NaN      NaN             NaN      NaN
# 5      5            NaN      NaN             NaN      NaN
# 6      6     $4,077,388     10.7    $378,815city      9.2
# 7      7            NaN      NaN             NaN      NaN
# 8      8       $879,465     15.7    $402,461city     12.6
# 9      9       $974,221     19.7    $937,500city     12.6
# 10    10       $931,944     14.5             NaN      NaN
# 11    11       $821,154     12.9    $529,360city     12.4
# 12    12     $1,508,360     14.5  $2,558,412city     29.6
# 13    13     $1,190,375     17.8    $844,083city     23.0
# 14    14            NaN      NaN             NaN      NaN
# ...
