# %% [markdown]
# # Scraping Addresses --> GPS coordinates
#
# ### Process
#
# 1. enter address (streets + san francisco)
# 2. get the GPS coordinates
# 3. then re-search the GPS
# 4. parse the ZIP from the return
# 5. Save the data

# %% [markdown]
# #### Libraries

# %%
import selenium
import time
from selenium import webdriver
import numpy as np
from selenium.webdriver.common.keys import Keys

# %%
driver = webdriver.Chrome('/Users/timlee/webdrivers/chromedriver')

# %%
# latbox = driver.find_element_by_xpath("//input[@id='latitude']")

# %%
# 37.711310	-122.404174

# %%
# latbox.clear()
# latbox.send_keys('37.711310')

# %%
# lonbox = driver.find_element_by_xpath("//input[@id='longitude']")
# lonbox.clear()
# lonbox.send_keys('-122.404174')

# %%
# submit = driver.find_element_by_xpath("//div[@class='form-group'][3]/div/button")
# submit.click()

# %%
# address_field = driver.find_element_by_id('address')

# %%
# address_field.get_attribute('value')
# Out:
# '15 Leland Ave, San Francisco, CA 94134, USA'

# %%
# from_word_addr = ["23rd Street and Bartlett Street, San Francisco"
# ,"23rd Street and Mission Street, San Francisco"
# ,"23rd Street and South Van Ness Avenue, San Francisco"
# ,"Battery Street and California Street, San Francisco"
# ,"Battery Street and Halleck Street, San Francisco"
# ,"Battery Street and Washington Street, San Francisco"
# ,"Bryant Street and Mariposa Street, San Francisco"
# ,"Bush Street and Parking Entrance Lane, San Francisco"
# ,"Bush Street and Taylor Street, San Francisco"
# ,"Columbus Avenue and Kearny Street, San Francisco"
# ,"Geary Street and Jones Street, San Francisco"
# ,"Geary Street and Larkin Street, San Francisco"
# ,"Geary Street and Leavenworth Street, San Francisco"
# ,"Grove Street and Dr Carlton P Goodlett Place, San Francisco"
# ,"Hyde Street and Golden Gate Avenue, San Francisco"
# ,"Jackson Street and Polk Street, San Francisco"
# ,"Jessie Street and New Montgomery Street, San Francisco"
# ,"Jones Street and Antonio Street, San Francisco"
# ,"Jones Street and Bush Street, San Francisco"
# ,"Jones Street and Colin Place, San Francisco"
# ,"Jones Street and Ellis Street, San Francisco"
# ,"Jones Street and Post Street, San Francisco"
# ,"Jones Street and Sutter Street, San Francisco"
# ,"Kearny Street and Geary Street, San Francisco"
# ,"Kearny Street and Hardie Place, San Francisco"
# ,"Kearny Street and Kearny Street, San Francisco"
# ,"Kearny Street and Nottingham Place, San Francisco"
# ,"Larkin Street and Cedar Street, San Francisco"
# ,"Larkin Street and Larkin Street, San Francisco"
# ,"Larkin Street and McAllister Street, San Francisco"
# ,"Larkin Street and Myrtle Street, San Francisco"
# ,"Larkin Street and O'Farrell Street, San Francisco"
# ,"Larkin Street and Sutter Street, San Francisco"
# ,"Larkin Street and Turk Street, San Francisco"
# ,"Leavenworth Street and Eddy Street, San Francisco"
# ,"Leavenworth Street and Turk Street, San Francisco"
# ,"Mason Street and Sutter Street, San Francisco"
# ,"Mission Street and 11th Street, San Francisco"
# ,"Mission Street and 25th Street, San Francisco"
# ,"Mission Street and 6th Street, San Francisco"
# ,"Mission Street and Julia Street, San Francisco"
,"Pine Street and Sansome Street"
,"Jones Street and Eddy Street"
,"Mission Street and 6th Street"
,"Kearny Street and Nottingham Place"
,"Polk Street and Elm Street"
,"Bryant Street and 17th Street"
,"Kearny Street and Bush Street"
,"Kearny Street and Maiden Lane"
,"Mission Street and Angelo's Alley"
,"Pine Street and Battery Street"
,"Kearny Street and Sutter Street"
,"Polk Street and Eddy Street"
,"Bush Street and Chatham Place"
,"Montgomery Street and Broadway"
]

# %% [markdown]
# ### Sensor Data locations

# %%
snsr_loc = [
"0 1ST ST"
,"200 1ST ST"
,"300 1ST ST"
,"200 2ND AVE"
,"300 2ND AVE"
,"0 2ND ST"
,"100 2ND ST"
,"200 2ND ST"
,"300 2ND ST"
,"400 2ND ST"
,"500 2ND ST"
,"600 2ND ST"
,"700 2ND ST"
,"200 3RD AVE"
,"300 3RD AVE"
,"300 3RD ST"
,"400 3RD ST"
,"500 3RD ST"
,"600 3RD ST"
,"700 3RD ST"
,"200 4TH AVE"
,"300 4TH AVE"
,"500 4TH ST"
,"600 4TH ST"
,"600 5TH ST"
,"200 7TH AVE"
,"200 9TH AVE"
,"300 9TH AVE"
,"200 10TH AVE"
,"300 10TH AVE"
,"2700 14TH AVE"
,"2800 14TH AVE"
,"2900 16TH ST"
,"3000 16TH ST"
,"3100 16TH ST"
,"3200 17TH ST"
,"3300 17TH ST"
,"3400 18TH ST"
,"3400 19TH ST"
,"3500 20TH ST"
,"3200 21ST ST"
,"3200 22ND ST"
,"3300 23RD ST"
,"0 AVILA ST"
,"0 BARTLETT ST"
,"200 BATTERY ST"
,"300 BATTERY ST"
,"400 BATTERY ST"
,"500 BATTERY ST"
,"300 BAY ST"
,"400 BAY ST"
,"500 BAY ST"
,"200 BEACH ST"
,"300 BEACH ST"
,"400 BEACH ST"
,"500 BEACH ST"
,"600 BEACH ST"
,"700 BEACH ST"
,"800 BEACH ST"
,"0 BEALE ST"
,"100 BERRY ST"
,"200 BERRY ST"
,"300 BERRY ST"
,"400 BERRY ST"
,"100 BRANNAN ST"
,"200 BRANNAN ST"
,"300 BRANNAN ST"
,"400 BRANNAN ST"
,"500 BRANNAN ST"
,"100 BRYANT ST"
,"300 BRYANT ST"
,"400 BRYANT ST"
,"500 BRYANT ST"
,"1800 BUCHANAN ST"
,"2900 BUCHANAN ST"
,"3000 BUCHANAN ST"
,"100 BUSH ST"
,"200 BUSH ST"
,"300 BUSH ST"
,"2300 CALIFORNIA ST"
,"2400 CALIFORNIA ST"
,"100 CAPP ST"
,"2000 CHESTNUT ST"
,"2100 CHESTNUT ST"
,"2200 CHESTNUT ST"
,"2300 CHESTNUT ST"
,"2400 CHESTNUT ST"
,"100 CLAY ST"
,"200 CLAY ST"
,"2400 CLAY ST"
,"2500 CLAY ST"
,"300 CLAY ST"
,"400 CLAY ST"
,"500 CLAY ST"
,"0 CLEMENT ST"
,"100 CLEMENT ST"
,"200 CLEMENT ST"
,"300 CLEMENT ST"
,"400 CLEMENT ST"
,"500 CLEMENT ST"
,"600 CLEMENT ST"
,"700 CLEMENT ST"
,"800 CLEMENT ST"
,"900 CLEMENT ST"
,"1200 COLUMBUS AVE"
,"1300 COLUMBUS AVE"
,"500 COMMERCIAL ST"
,"Lot California and Steiner"
,"0 DAVIS ST"
,"100 DAVIS ST"
,"200 DAVIS ST"
,"300 DAVIS ST"
,"600 DELANCEY ST"
,"3200 DIVISADERO ST"
,"0 DRUMM ST"
,"100 DRUMM ST"
,"200 DRUMM ST"
,"300 DRUMM ST"
,"0 EMBARCADERO NORTH"
,"100 EMBARCADERO NORTH"
,"200 EMBARCADERO NORTH"
,"0 EMBARCADERO SOUTH"
,"200 EMBARCADERO SOUTH"
,"300 EMBARCADERO SOUTH"
,"400 EMBARCADERO SOUTH"
,"500 EMBARCADERO SOUTH"
,"600 EMBARCADERO SOUTH"
,"0 FELL ST"
,"100 FELL ST"
,"200 FELL ST"
,"300 FELL ST"
,"2100 FILBERT ST"
,"2200 FILBERT ST"
,"1000 FILLMORE ST"
,"1100 FILLMORE ST"
,"1200 FILLMORE ST"
,"1300 FILLMORE ST"
,"1400 FILLMORE ST"
,"1500 FILLMORE ST"
,"1600 FILLMORE ST"
,"1700 FILLMORE ST"
,"1800 FILLMORE ST"
,"1900 FILLMORE ST"
,"2000 FILLMORE ST"
,"2100 FILLMORE ST"
,"2200 FILLMORE ST"
,"2300 FILLMORE ST"
,"2400 FILLMORE ST"
,"2900 FILLMORE ST"
,"3000 FILLMORE ST"
,"3100 FILLMORE ST"
,"3200 FILLMORE ST"
,"3300 FILLMORE ST"
,"0 FOLSOM ST"
,"500 FOLSOM ST"
,"600 FOLSOM ST"
,"100 FRANKLIN ST"
,"200 FRANKLIN ST"
,"300 FRANKLIN ST"
,"400 FRANKLIN ST"
,"500 FRANKLIN ST"
,"0 FREMONT ST"
,"200 FREMONT ST"
,"0 FRONT ST"
,"100 FRONT ST"
,"200 FRONT ST"
,"300 FRONT ST"
,"1500 GEARY BLVD"
,"1600 GEARY BLVD"
,"1700 GEARY BLVD"
,"1800 GEARY BLVD"
,"3700 GEARY BLVD"
,"3800 GEARY BLVD"
,"3900 GEARY BLVD"
,"4000 GEARY BLVD"
,"4100 GEARY BLVD"
,"4200 GEARY BLVD"
,"4300 GEARY BLVD"
,"4400 GEARY BLVD"
,"4500 GEARY BLVD"
,"4600 GEARY BLVD"
,"600 GOLDEN GATE AVE"
,"700 GOLDEN GATE AVE"
,"200 GOUGH ST"
,"300 GOUGH ST"
,"400 GOUGH ST"
,"500 GOUGH ST"
,"2100 GREENWICH ST"
,"2200 GREENWICH ST"
,"0 GROVE ST"
,"100 GROVE ST"
,"200 GROVE ST"
,"300 GROVE ST"
,"200 HALLECK ST"
,"0 HARRISON ST"
,"100 HARRISON ST"
,"500 HARRISON ST"
,"600 HARRISON ST"
,"0 HAWTHORNE ST"
,"100 HAWTHORNE ST"
,"0 HAYES ST"
,"100 HAYES ST"
,"200 HAYES ST"
,"300 HAYES ST"
,"400 HAYES ST"
,"500 HAYES ST"
,"0 HICKORY ST"
,"100 HICKORY ST"
,"0 HOFF ST"
,"0 HOWARD ST"
,"100 HOWARD ST"
,"600 HOWARD ST"
,"2800 HYDE ST"
,"0 JACKSON ST"
,"100 JACKSON ST"
,"200 JACKSON ST"
,"2300 JACKSON ST"
,"2400 JACKSON ST"
,"300 JACKSON ST"
,"400 JACKSON ST"
,"0 JEFFERSON ST"
,"100 JEFFERSON ST"
,"200 JEFFERSON ST"
,"300 JEFFERSON ST"
,"400 JEFFERSON ST"
,"500 JEFFERSON ST"
,"100 JESSIE ST"
,"2600 JONES ST"
,"2700 JONES ST"
,"2800 JONES ST"
,"0 KEARNY ST"
,"100 KEARNY ST"
,"200 KEARNY ST"
,"300 KEARNY ST"
,"400 KEARNY ST"
,"100 KING ST"
,"200 KING ST"
,"700 KING ST"
,"1500 LAGUNA ST"
,"1600 LAGUNA ST"
,"2800 LAGUNA ST"
,"2900 LAGUNA ST"
,"0 LARKIN ST"
,"100 LARKIN ST"
,"200 LARKIN ST"
,"3000 LARKIN ST"
,"2700 LEAVENWORTH ST"
,"2800 LEAVENWORTH ST"
,"0 LECH WALESA ST"
,"2000 LOMBARD ST"
,"2100 LOMBARD ST"
,"2200 LOMBARD ST"
,"2300 LOMBARD ST"
,"2400 LOMBARD ST"
,"0 MAIN ST"
,"300 MAIN ST"
,"0 MALLORCA WAY"
,"0 MARKET ST"
,"2300 MASON ST"
,"2400 MASON ST"
,"2500 MASON ST"
,"2600 MASON ST"
,"300 MCALLISTER ST"
,"400 MCALLISTER ST"
,"500 MCALLISTER ST"
,"400 MERCHANT ST"
,"100 MINNA ST"
,"0 MISSION ST"
,"100 MISSION ST"
,"2000 MISSION ST"
,"2100 MISSION ST"
,"2200 MISSION ST"
,"2300 MISSION ST"
,"2400 MISSION ST"
,"2500 MISSION ST"
,"2600 MISSION ST"
,"2700 MISSION ST"
,"600 MISSION ST"
,"0 MONTGOMERY ST"
,"100 MONTGOMERY ST"
,"200 MONTGOMERY ST"
,"300 MONTGOMERY ST"
,"400 MONTGOMERY ST"
,"500 MONTGOMERY ST"
,"600 MONTGOMERY ST"
,"700 MONTGOMERY ST"
,"100 NATOMA ST"
,"0 NEW MONTGOMERY ST"
,"100 NEW MONTGOMERY ST"
,"100 NORTH POINT ST"
,"200 NORTH POINT ST"
,"300 NORTH POINT ST"
,"400 NORTH POINT ST"
,"500 NORTH POINT ST"
,"600 NORTH POINT ST"
,"900 NORTH POINT ST"
,"0 OAK ST"
,"100 OAK ST"
,"2700 OCTAVIA ST"
,"2800 OCTAVIA ST"
,"3200 PIERCE ST"
,"3300 PIERCE ST"
,"0 PINE ST"
,"100 PINE ST"
,"200 PINE ST"
,"2300 PINE ST"
,"300 PINE ST"
,"400 PINE ST"
,"100 PIXLEY ST"
,"200 PIXLEY ST"
,"0 POLK ST"
,"100 POLK ST"
,"200 POLK ST"
,"300 POLK ST"
,"3100 POLK ST"
,"0 POST ST"
,"1600 POST ST"
,"1700 POST ST"
,"1800 POST ST"
,"1900 POST ST"
,"2300 POWELL ST"
,"2400 POWELL ST"
,"100 REDWOOD ST"
,"300 RITCH ST"
,"100 SACRAMENTO ST"
,"200 SACRAMENTO ST"
,"2400 SACRAMENTO ST"
,"2500 SACRAMENTO ST"
,"300 SACRAMENTO ST"
,"400 SACRAMENTO ST"
,"500 SACRAMENTO ST"
,"0 SANSOME ST"
,"100 SANSOME ST"
,"200 SANSOME ST"
,"300 SANSOME ST"
,"400 SANSOME ST"
,"500 SANSOME ST"
,"600 SANSOME ST"
,"3200 SCOTT ST"
,"3300 SCOTT ST"
,"0 SOUTH PARK"
,"100 SOUTH PARK"
,"0 SPEAR ST"
,"100 SPEAR ST"
,"200 SPEAR ST"
,"300 SPEAR ST"
,"400 SPEAR ST"
,"1500 STEINER ST"
,"3300 STEINER ST"
,"0 STEUART ST"
,"100 STEUART ST"
,"200 STEUART ST"
,"0 STEVENSON ST"
,"2300 STOCKTON ST"
,"0 SUTTER ST"
,"100 SUTTER ST"
,"1800 SUTTER ST"
,"2000 SUTTER ST"
,"2500 TAYLOR ST"
,"2600 TAYLOR ST"
,"2700 TAYLOR ST"
,"100 TEHAMA ST"
,"0 TOWNSEND ST"
,"100 TOWNSEND ST"
,"200 TOWNSEND ST"
,"300 TOWNSEND ST"
,"1700 UNION ST"
,"1800 UNION ST"
,"1900 UNION ST"
,"2000 UNION ST"
,"2100 UNION ST"
,"2200 UNION ST"
,"1000 VALENCIA ST"
,"1100 VALENCIA ST"
,"1200 VALENCIA ST"
,"400 VALENCIA ST"
,"500 VALENCIA ST"
,"600 VALENCIA ST"
,"700 VALENCIA ST"
,"800 VALENCIA ST"
,"900 VALENCIA ST"
,"0 VAN NESS AVE"
,"100 VAN NESS AVE"
,"200 VAN NESS AVE"
,"300 VAN NESS AVE"
,"400 VAN NESS AVE"
,"500 VAN NESS AVE"
,"0 VICENTE ST"
,"100 VICENTE ST"
,"0 WASHINGTON ST"
,"100 WASHINGTON ST"
,"200 WASHINGTON ST"
,"2400 WASHINGTON ST"
,"2500 WASHINGTON ST"
,"300 WASHINGTON ST"
,"400 WASHINGTON ST"
,"500 WASHINGTON ST"
,"1500 WEBSTER ST"
,"1600 WEBSTER ST"
,"2100 WEBSTER ST"
,"2200 WEBSTER ST"
,"2800 WEBSTER ST"
,"2900 WEBSTER ST"
,"0 WEST PORTAL AVE"
,"100 WEST PORTAL AVE"
,"200 WEST PORTAL AVE"
,"300 WEST PORTAL AVE"
]

# %%
with open('./all_lat_lon.csv', 'r') as f:
    all_lat_lon = f.read().split('\n')
    all_lat_lon = [v.split(',') for v in all_lat_lon]

# %%
print(len(tt_word_addr))
# Out:
# 158

# %%
driver = webdriver.Chrome('/Users/timlee/webdrivers/chromedriver')

# %%
driver.get('https://www.gps-coordinates.net/gps-coordinates-converter')

# %%
def intersection_search():
    offset = 0
    for i, word_addr  in enumerate(snsr_loc[offset:]):
        address_box = driver.find_element_by_xpath("//input[@id='address']")
        address_box.clear()
        address_box.send_keys(word_addr + ', San Francisco')
        address_box.send_keys(Keys.ENTER)
        submit = driver.find_element_by_xpath("//div[@class='form-group'][2]/div/button")
        submit.click()
        time.sleep(1)
        address_field = driver.find_element_by_id('address')
        latbox = driver.find_element_by_xpath("//input[@id='latitude']")
        lat_val = latbox.get_attribute('value')
        lonbox = driver.find_element_by_xpath("//input[@id='longitude']")
        lon_val = lonbox.get_attribute('value')
        submit = driver.find_element_by_xpath("//div[@class='form-group'][3]/div/button")
        submit.click()
        time.sleep(1)
        addr_val = address_field.get_attribute('value')
        ad1 = word_addr.split(' and ')[0]
        ad2 = word_addr.split(' and ')[1]
        zipc = addr_val[-10:-5]
        output = [str(i+offset), ad1, ad2, lat_val, lon_val, zipc]
        print('|'.join(output))

# %%
def single_search():
    offset = 352
    for i, word_addr  in enumerate(snsr_loc[offset:]):
        address_box = driver.find_element_by_xpath("//input[@id='address']")
        address_box.clear()
        address_box.send_keys(word_addr + ', San Francisco')
        address_box.send_keys(Keys.ENTER)
        submit = driver.find_element_by_xpath("//div[@class='form-group'][2]/div/button")
        submit.click()
        time.sleep(1)
        address_field = driver.find_element_by_id('address')
        latbox = driver.find_element_by_xpath("//input[@id='latitude']")
        lat_val = latbox.get_attribute('value')
        lonbox = driver.find_element_by_xpath("//input[@id='longitude']")
        lon_val = lonbox.get_attribute('value')
        submit = driver.find_element_by_xpath("//div[@class='form-group'][3]/div/button")
        submit.click()
        time.sleep(1)
        addr_val = address_field.get_attribute('value')
        ad1 = word_addr
        zipc = addr_val[-10:-5]
        output = [str(i+offset), ad1, lat_val, lon_val, zipc]
        print('|'.join(output))

single_search()
# Out:
# 352|0 STEVENSON ST|37.7905944|-122.3986261|94105
# 353|2300 STOCKTON ST|37.8072728|-122.41034350000001|94133
# 354|0 SUTTER ST|37.7902627|-122.40060590000002|94104
# 355|100 SUTTER ST|37.7900396|-122.40221930000001|94104
# 356|1800 SUTTER ST|37.7866599|-122.4302707|94115
# 357|2000 SUTTER ST|37.786093|-122.43331310000002|94115
# 358|2500 TAYLOR ST|37.8054433|-122.41526829999998|94133
# 359|2600 TAYLOR ST|37.8063649|-122.41545580000002|94133
# 360|2700 TAYLOR ST|37.8073043|-122.41564299999999|94133
# 361|100 TEHAMA ST|37.7863516|-122.3977299|94105
# 362|0 TOWNSEND ST|37.781806|-122.38870930000002|94107
# 363|100 TOWNSEND ST|37.78055|-122.39104800000001|94107
# 364|200 TOWNSEND ST|37.7789009|-122.39324799999997|ed ad
# 365|300 TOWNSEND ST|37.7772336|-122.39483100000001|94107
# 366|1700 UNION ST|37.7982747|-122.4274378|94123
# 367|1800 UNION ST|37.7981222|-122.42913970000001|ed ad
# 368|1900 UNION ST|37.7979584|-122.43096230000003|94123
# ...

# %%
import pandas as pd
df = pd.read_csv('../ref_data/sensor_2_gps.txt', delimiter = '|', header=None)
df.columns = ['id', 'street', 'lat','lon','zip']
follow_up = df[df['zip']== 'ed ad'][['id','lat','lon']].values

# %%
miss_df = pd.DataFrame(missingzips)
miss_df = miss_df[miss_df.iloc[:,3] != 'No resolved address'].copy()
miss_df['id'] = miss_df.iloc[:,0].astype(int)
miss_df['zip'] = miss_df.iloc[:,3].str[-10:-5]
miss_df.index = miss_df['id']
miss_df = miss_df['zip'].copy()
df.loc[df['zip']== 'ed ad','zip'] = df.loc[df['zip']== 'ed ad','id'].map(miss_df)
follow_up = df[df['zip'].isna()][['id','lat','lon']].values

# %%
miss_df = pd.DataFrame(missingzips)
miss_df = miss_df[miss_df.iloc[:,3] != 'No resolved address'].copy()
miss_df['id'] = miss_df.iloc[:,0].astype(int)
miss_df['zip'] = miss_df.iloc[:,3].str[-10:-5]
miss_df.index = miss_df['id']
miss_df = miss_df['zip'].copy()
df.loc[df['zip'].isna(),'zip'] = df.loc[df['zip'].isna(),'id'].map(miss_df)
follow_up = df[df['zip'].isna()][['id','lat','lon']].values

# %%
follow_up
# Out:
# array([], shape=(0, 3), dtype=float64)

# %%
import pandas as pd
missingzips = []
for id_, lat, lon in follow_up:
    latbox = driver.find_element_by_xpath("//input[@id='latitude']")
    latbox.clear()
    latbox.send_keys(str(lat))
    lonbox = driver.find_element_by_xpath("//input[@id='longitude']")
    lonbox.clear()
    lonbox.send_keys(str(lon))
    submit = driver.find_element_by_xpath("//div[@class='form-group'][3]/div/button")
    submit.click()
    time.sleep(1)
    address_field = driver.find_element_by_id('address')
    addr_val = address_field.get_attribute('value')
    
    print(id_, lat, lon ,addr_val)
    missingzips.append([id_, lat, lon ,addr_val])
# Out:
# 380.0 37.7583973 -122.4215428 900 Valencia St, San Francisco, CA 94110, USA
# 401.0 37.7963829 -122.4336822 2800 Webster St, San Francisco, CA 94123, USA

# %%
df.to_csv('../ref_data/sensor_2_gps.txt', sep = '|', header=None, index=False)

# %%
driver = webdriver.Chrome('/Users/timlee/webdrivers/chromedriver')

# %%
driver.get('https://www.gps-coordinates.net/gps-coordinates-converter')

# %%
lkup = {
13 	: 94102,
16 	: 94111,
18 	: 94102,
21 	: 94109,
24 	: 94102,
26 	: 94109,
29 	: 94102,
31 	: 94109,
34 	: 94133,
36 	: 94111,
39 	: 94102,
41 	: 94102,
43 	: 94109,
46 	: 94102,
48 	: 94109,
50 	: 94109,
52 	: 94102,
55 	: 94109,
57 	: 94133,
61 	: 94109,
62 	: 94104,
64 	: 94109,
68 	: 94102,
83 	: 94102,
98 	: 94109,
101	: 94102,
104	: 94102,
110	: 94102,
112	: 94108,
117	: 94102,
119	: 94109,
123	: 94109,
126	: 94108,
128	: 94109,
132	: 94111,
134	: 94104,
137	: 94110,
139	: 94102,
142	: 94102,
144	: 94104,
146	: 94103,
149	: 94110,
150	: 94108,
153	: 94104,
154	: 94108,
157	: 94133,
59  : 94102 ,
66  : 94102 ,
96  : 94109 ,
107 : 94133 ,
114 : 94109 ,
121 : 94111 ,
130 : 94109 ,
135 : 94102 ,
141 : 94109 ,
147 : 94133 ,
152 : 94103 ,
156 : 94108 
}

# %%
tmp = pd.read_csv('train_test_addr_gps.txt', delimiter = '|', header=None)
tmp.columns = ['id','Street','From_To', 'lat','long','zip']
for k, v in lkup.items():
    tmp.iloc[k,5] = v

print(tmp.to_csv(sep='|', index=False))
# Out:
# id|Street|From_To|lat|long|zip
# 0|Taylor Street|Geary Street|37.786946500000006|-122.41154790000002|94102
# 1|Van Ness Avenue|Turk Street|37.7819764|-122.4205794|94102
# 2|Jones Street|Sutter Street|37.7886086|-122.41356480000002|94109
# 3|Van Ness Avenue|Alice B. Toklas Place|37.785244399999996|-122.4212351|94109
# 4|Bush Street|Taylor Street|37.7897577|-122.412102|94108
# 5|Mission Street|25th Street|37.7506482|-122.41831589999998|94110
# 6|23rd Street|Bartlett Street|37.7537794|-122.41972909999998|94110
# 7|Battery Street|Halleck Street|37.7937021|-122.40008469999998|94111
# 8|Mission Street|7th Street|37.7792143|-122.41096280000001|94103
# 9|Polk Street|O'Farrell Street|37.78497480000001|-122.41957200000002|94109
# 10|Leavenworth Street|Ellis Street|37.7846684|-122.41445169999996|94102
# 11|Columbus Avenue|Kearny Street|37.7969361|-122.40531940000001|94133
# 12|Kearny Street|Geary Street|37.7879767|-122.40350820000003|94108
# ...

# %%
import pandas as pd
for row in tmp[tmp.zip == 'ed ad'].values:
    latbox = driver.find_element_by_xpath("//input[@id='latitude']")
    latbox.clear()
    latbox.send_keys(str(row[3]))
    lonbox = driver.find_element_by_xpath("//input[@id='longitude']")
    lonbox.clear()
    lonbox.send_keys(str(row[4]))
    submit = driver.find_element_by_xpath("//div[@class='form-group'][3]/div/button")
    submit.click()
    time.sleep(1)
    address_field = driver.find_element_by_id('address')
    addr_val = address_field.get_attribute('value')
    
    print(row[0],addr_val)
# Out:
# 59 98 Grove St, San Francisco, CA 94102, USA
# 66 66 Grove St, San Francisco, CA 94102, USA
# 96 2164-2198 Polk St, San Francisco, CA 94109, USA
# 107 800 Montgomery St, San Francisco, CA 94133, USA
# 114 501 Larkin St, San Francisco, CA 94109, USA
# 121 598 Commercial St, San Francisco, CA 94111, USA
# 130 1801 Polk St, San Francisco, CA 94109, USA
# 135 300 Van Ness Ave, San Francisco, CA 94102, USA
# 141 1700 Clay St, San Francisco, CA 94109, USA
# 147 1028 Kearny St, San Francisco, CA 94133, USA
# 152 2 Angelo's Alley, San Francisco, CA 94103, USA
# 156 549 Bush St, San Francisco, CA 94108, USA

# %%
to_word_addr[83]
# Out:
# 'Van Ness Avenue Post Street, San Francisco'

# %%
# offset = 0
# for i, word_addr  in enumerate(to_word_addr[offset:]):
#     address_box = driver.find_element_by_xpath("//input[@id='address']")
#     address_box.clear()
#     address_box.send_keys(word_addr)
#     address_box.send_keys(Keys.ENTER)
#     submit = driver.find_element_by_xpath("//div[@class='form-group'][2]/div/button")
#     submit.click()
#     time.sleep(1)
#     address_field = driver.find_element_by_id('address')
#     latbox = driver.find_element_by_xpath("//input[@id='latitude']")
#     lat_val = latbox.get_attribute('value')
#     lonbox = driver.find_element_by_xpath("//input[@id='longitude']")
#     lon_val = lonbox.get_attribute('value')
#     submit = driver.find_element_by_xpath("//div[@class='form-group'][3]/div/button")
#     submit.click()
#     time.sleep(1)
#     addr_val = address_field.get_attribute('value')
#     ad1 = word_addr.split(' and ')[0]
#     ad2 = word_addr.split(' and ')[1][:-15]
#     zipc = addr_val[-10:-5]
#     output = [str(i+offset), ad1, ad2, lat_val, lon_val, zipc]
#     print('|'.join(output))
# Out:
# 0 23rd Street and Bartlett Street, San Francisco | 37.7537794 | -122.41972909999998
# 1 23rd Street and Capp Street, San Francisco | 37.7539117 | -122.41752940000003
# 2 23rd Street and Valencia Street, San Francisco | 37.7537066 | -122.42083580000002
# 3 Battery Street and California Street, San Francisco | 37.7932237 | -122.39998930000002
# 4 Battery Street and Merchant Street, San Francisco | 37.7954607 | -122.4004453
# 5 Battery Street and Pine Street, San Francisco | 37.7922635 | -122.3997971
# 6 Bryant Street and 17th Street, San Francisco | 37.7643177 | -122.41038379999998
# 7 Bush Street and Chatham Place, San Francisco | 37.790473 | -122.40635129999998
# 8 Bush Street and Mason Street, San Francisco | 37.7899599 | -122.41045539999999
# 9 Columbus Avenue and Pacific Avenue, San Francisco | 37.7970734 | -122.40555760000001
# 10 Geary Street and Geary Street, San Francisco | 37.7856601 | -122.42147640000002
# ...

# %%
driver.get('https://www.gps-coordinates.net/gps-coordinates-converter')
with open ('./all_addresses.csv', 'w') as f:
    for i, zzcoord  in enumerate(all_lat_lon):
#         lat, lon = coord
#         latbox = driver.find_element_by_xpath("//input[@id='latitude']")
#         latbox.clear()
#         latbox.send_keys(lat)
        
#         lonbox = driver.find_element_by_xpath("//input[@id='longitude']")
#         lonbox.clear()
#         lonbox.send_keys(lon)
        address_box = driver.find_element_by_xpath("//input[@id='address']")
        address_box.clear()
        address_box.send_keys()
    
        submit = driver.find_element_by_xpath("//div[@class='form-group'][3]/div/button")
        submit.click()
        
        address_field = driver.find_element_by_id('address')
        addr_val = address_field.get_attribute('value')
        
        f.write("%s|%s|%s \n" %(lat, lon, addr_val))
        time.sleep(np.random.randint(1,10)/5)
        if i % 25 == 0 :
            print(i,)
# Out:
# 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-abbec22727c0> in <module>()
#      21
#      22         f.write("%s|%s|%s \n" %(lat, lon, addr_val))
# ---> 23         time.sleep(np.random.randint(1,10)/5)
#      24         if i % 25 == 0 :
#      25             print(i,)
#
# KeyboardInterrupt:
